# %% [markdown]
# # <font color=blue><div align="center">Seats Allocation within an Aircraft</div></font>
#
# ### <font color=blue><div align="center">29-02-2024</div></font>

# %% [markdown]
# ## Modules

# %%
# Basic modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import Table
import random

# Gurobi module
from gurobipy import *

# %% [markdown]
# ## Data Extraction

# %%
# Load the Excel file into a pandas DataFrame


df_21Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=0 , skipfooter=2)
df_22Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=1 , skipfooter=2)
df_23Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=2 , skipfooter=2)
df_24Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=3 , skipfooter=2)
df_30Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=4 , skipfooter=2)
df_05Nov = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=5 , skipfooter=2)
df_07Nov = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=6 , skipfooter=2)

# %%
# Display the DataFrame
df = df_07Nov
df
# Out:
#     Numéro du groupe  Femmes  Hommes  WCHR TransitTime
# 0                  1     1.0     NaN   NaN    00:55:00
# 1                  2     NaN     1.0   NaN    00:00:00
# 2                  3     1.0     NaN   NaN    01:15:00
# 3                  4     1.0     1.0   NaN    03:15:00
# 4                  5     1.0     NaN   NaN    00:00:00
# ..               ...     ...     ...   ...         ...
# 84                85     NaN     2.0   NaN    00:00:00
# 85                86     1.0     NaN   1.0    00:00:00
# 86                87     1.0     NaN   NaN    03:15:00
# 87                88     2.0     1.0   NaN    00:00:00
# 88                89     2.0     1.0   NaN    00:00:00
#
# [89 rows x 5 columns]

# %% [markdown]
# The code in the cells below creates a dictionary Passengers defined as follows:
#
# - Passengers Keys: IDs of passengers.
# - Passengers Items: For each ID in Passengers, we specify its *type* (female: 0, male: 1, disabled: 2), its *group number*, and its *transit time*.
#
# Notice that for passengers with a transit time equal to 0 or larger than 2 hours, the transit time in the dictionary is set to $\infty$

# %%
def convert_TransitTime(time_val):

    # Convert time to minutes
    total_minutes = time_val.hour * 60 + time_val.minute
    
    # Check if total minutes is greater than 2 hours or equal to 0
    if total_minutes > 120 or total_minutes == 0:
        return float('inf')  # Return infinity
    else:
        return total_minutes

df['TransitTime'] = df['TransitTime'].apply(convert_TransitTime)

# %%
# Create Passengers dictionary
Passengers = dict()
i = 1

number_f = 0
number_m = 0
number_d = 0

transit_times = set()

# Groups : dict[int : List[int]]

Passengers = dict()
i = 1

for group in df.itertuples():
    if not pd.isna(group[2]):
        for k in range(int(group[2])):
            Passengers[i] = {'type': 0, 'group':group[1], 'transit':group[5]}
            number_f += 1
            transit_times.add(group[5])
            i+=1
    if not pd.isna(group[3]):
        for k in range(int(group[3])):
            Passengers[i] = {'type': 1, 'group':group[1], 'transit':group[5]}
            number_m += 1
            transit_times.add(group[5])
            i+=1
    if not pd.isna(group[4]):
        for k in range(int(group[4])):
            Passengers[i] = {'type': 2, 'group':group[1], 'transit':group[5]}
            number_d += 1
            transit_times.add(group[5])
            i+=1
    


    
Passengers
# Out:
# {1: {'type': 0, 'group': 1, 'transit': 55.0},
#  2: {'type': 1, 'group': 2, 'transit': inf},
#  3: {'type': 0, 'group': 3, 'transit': 75.0},
#  4: {'type': 0, 'group': 4, 'transit': inf},
#  5: {'type': 1, 'group': 4, 'transit': inf},
#  6: {'type': 0, 'group': 5, 'transit': inf},
#  7: {'type': 0, 'group': 6, 'transit': inf},
#  8: {'type': 0, 'group': 6, 'transit': inf},
#  9: {'type': 2, 'group': 7, 'transit': inf},
#  10: {'type': 0, 'group': 8, 'transit': inf},
#  11: {'type': 1, 'group': 8, 'transit': inf},
#  12: {'type': 1, 'group': 8, 'transit': inf},
#  13: {'type': 1, 'group': 8, 'transit': inf},
#  14: {'type': 1, 'group': 8, 'transit': inf},
#  15: {'type': 0, 'group': 9, 'transit': inf},
#  16: {'type': 0, 'group': 9, 'transit': inf},
#  17: {'type': 0, 'group': 9, 'transit': inf},
#  18: {'type': 0, 'group': 9, 'transit': inf},
#  19: {'type': 0, 'group': 10, 'transit': inf},
#  20: {'type': 0, 'group': 11, 'transit': inf},
#  21: {'type': 1, 'group': 11, 'transit': inf},
#  22: {'type': 0, 'group': 12, 'transit': inf},
#  23: {'type': 0, 'group': 12, 'transit': inf},
#  24: {'type': 0, 'group': 12, 'transit': inf},
#  25: {'type': 0, 'group': 12, 'transit': inf},
#  26: {'type': 0, 'group': 12, 'transit': inf},
#  27: {'type': 0, 'group': 13, 'transit': 75.0},
#  28: {'type': 0, 'group': 13, 'transit': 75.0},
#  29: {'type': 2, 'group': 13, 'transit': 75.0},
#  30: {'type': 2, 'group': 13, 'transit': 75.0},
#  31: {'type': 0, 'group': 14, 'transit': 55.0},
#  32: {'type': 0, 'group': 14, 'transit': 55.0},
#  33: {'type': 0, 'group': 14, 'transit': 55.0},
#  34: {'type': 0, 'group': 14, 'transit': 55.0},
#  35: {'type': 1, 'group': 14, 'transit': 55.0},
#  36: {'type': 0, 'group': 15, 'transit': inf},
#  37: {'type': 2, 'group': 16, 'transit': 55.0},
#  38: {'type': 0, 'group': 17, 'transit': inf},
#  39: {'type': 1, 'group': 17, 'transit': inf},
#  40: {'type': 0, 'group': 18, 'transit': 75.0},
#  41: {'type': 0, 'group': 18, 'transit': 75.0},
#  42: {'type': 0, 'group': 18, 'transit': 75.0},
#  43: {'type': 0, 'group': 18, 'transit': 75.0},
#  44: {'type': 0, 'group': 18, 'transit': 75.0},
#  45: {'type': 0, 'group': 19, 'transit': inf},
#  46: {'type': 0, 'group': 20, 'transit': 75.0},
#  47: {'type': 0, 'group': 20, 'transit': 75.0},
#  48: {'type': 2, 'group': 21, 'transit': inf},
#  49: {'type': 0, 'group': 22, 'transit': inf},
#  50: {'type': 0, 'group': 23, 'transit': inf},
#  51: {'type': 1, 'group': 23, 'transit': inf},
#  52: {'type': 1, 'group': 23, 'transit': inf},
#  53: {'type': 0, 'group': 24, 'transit': 75.0},
#  54: {'type': 0, 'group': 24, 'transit': 75.0},
#  55: {'type': 0, 'group': 24, 'transit': 75.0},
#  56: {'type': 0, 'group': 24, 'transit': 75.0},
#  57: {'type': 0, 'group': 25, 'transit': inf},
#  58: {'type': 1, 'group': 26, 'transit': 55.0},
#  59: {'type': 2, 'group': 26, 'transit': 55.0},
#  60: {'type': 2, 'group': 26, 'transit': 55.0},
#  61: {'type': 0, 'group': 27, 'transit': inf},
#  62: {'type': 1, 'group': 27, 'transit': inf},
#  63: {'type': 1, 'group': 28, 'transit': inf},
#  64: {'type': 1, 'group': 29, 'transit': inf},
#  65: {'type': 1, 'group': 30, 'transit': inf},
#  66: {'type': 0, 'group': 31, 'transit': inf},
#  67: {'type': 0, 'group': 32, 'transit': inf},
#  68: {'type': 1, 'group': 33, 'transit': 55.0},
#  69: {'type': 1, 'group': 34, 'transit': inf},
#  70: {'type': 0, 'group': 35, 'transit': inf},
#  71: {'type': 0, 'group': 36, 'transit': 55.0},
#  72: {'type': 1, 'group': 36, 'transit': 55.0},
#  73: {'type': 0, 'group': 37, 'transit': inf},
#  74: {'type': 0, 'group': 38, 'transit': inf},
#  75: {'type': 0, 'group': 38, 'transit': inf},
#  76: {'type': 1, 'group': 38, 'transit': inf},
#  77: {'type': 0, 'group': 39, 'transit': inf},
#  78: {'type': 1, 'group': 39, 'transit': inf},
#  79: {'type': 1, 'group': 40, 'transit': inf},
#  80: {'type': 1, 'group': 41, 'transit': inf},
#  81: {'type': 1, 'group': 41, 'transit': inf},
#  82: {'type': 0, 'group': 42, 'transit': 55.0},
#  83: {'type': 1, 'group': 42, 'transit': 55.0},
#  84: {'type': 1, 'group': 43, 'transit': 75.0},
#  85: {'type': 1, 'group': 44, 'transit': inf},
#  86: {'type': 1, 'group': 45, 'transit': inf},
#  87: {'type': 0, 'group': 46, 'transit': inf},
#  88: {'type': 0, 'group': 46, 'transit': inf},
#  89: {'type': 0, 'group': 46, 'transit': inf},
#  90: {'type': 0, 'group': 46, 'transit': inf},
#  91: {'type': 0, 'group': 46, 'transit': inf},
#  92: {'type': 0, 'group': 47, 'transit': inf},
#  93: {'type': 1, 'group': 48, 'transit': inf},
#  94: {'type': 1, 'group': 49, 'transit': inf},
#  95: {'type': 1, 'group': 50, 'transit': inf},
#  96: {'type': 1, 'group': 51, 'transit': inf},
#  97: {'type': 2, 'group': 51, 'transit': inf},
#  98: {'type': 0, 'group': 52, 'transit': inf},
#  99: {'type': 0, 'group': 53, 'transit': inf},
#  100: {'type': 1, 'group': 54, 'transit': inf},
#  101: {'type': 1, 'group': 55, 'transit': inf},
#  102: {'type': 1, 'group': 56, 'transit': inf},
#  103: {'type': 0, 'group': 57, 'transit': inf},
#  104: {'type': 0, 'group': 57, 'transit': inf},
#  105: {'type': 1, 'group': 57, 'transit': inf},
#  106: {'type': 1, 'group': 57, 'transit': inf},
#  107: {'type': 1, 'group': 58, 'transit': inf},
#  108: {'type': 1, 'group': 59, 'transit': inf},
#  109: {'type': 1, 'group': 60, 'transit': inf},
#  110: {'type': 1, 'group': 60, 'transit': inf},
#  111: {'type': 1, 'group': 61, 'transit': inf},
#  112: {'type': 0, 'group': 62, 'transit': inf},
#  113: {'type': 1, 'group': 63, 'transit': 75.0},
#  114: {'type': 1, 'group': 64, 'transit': 55.0},
#  115: {'type': 0, 'group': 65, 'transit': inf},
#  116: {'type': 0, 'group': 65, 'transit': inf},
#  117: {'type': 1, 'group': 65, 'transit': inf},
#  118: {'type': 1, 'group': 65, 'transit': inf},
#  119: {'type': 0, 'group': 66, 'transit': inf},
#  120: {'type': 0, 'group': 67, 'transit': inf},
#  121: {'type': 1, 'group': 67, 'transit': inf},
#  122: {'type': 1, 'group': 68, 'transit': inf},
#  123: {'type': 1, 'group': 69, 'transit': inf},
#  124: {'type': 1, 'group': 70, 'transit': inf},
#  125: {'type': 0, 'group': 71, 'transit': inf},
#  126: {'type': 1, 'group': 72, 'transit': 55.0},
#  127: {'type': 0, 'group': 73, 'transit': 75.0},
#  128: {'type': 1, 'group': 73, 'transit': 75.0},
#  129: {'type': 0, 'group': 74, 'transit': inf},
#  130: {'type': 0, 'group': 74, 'transit': inf},
#  131: {'type': 1, 'group': 74, 'transit': inf},
#  132: {'type': 0, 'group': 75, 'transit': inf},
#  133: {'type': 0, 'group': 75, 'transit': inf},
#  134: {'type': 1, 'group': 75, 'transit': inf},
#  135: {'type': 0, 'group': 76, 'transit': inf},
#  136: {'type': 1, 'group': 76, 'transit': inf},
#  137: {'type': 1, 'group': 77, 'transit': inf},
#  138: {'type': 1, 'group': 78, 'transit': inf},
#  139: {'type': 1, 'group': 79, 'transit': inf},
#  140: {'type': 1, 'group': 79, 'transit': inf},
#  141: {'type': 1, 'group': 80, 'transit': 75.0},
#  142: {'type': 0, 'group': 81, 'transit': 55.0},
#  143: {'type': 1, 'group': 81, 'transit': 55.0},
#  144: {'type': 0, 'group': 82, 'transit': inf},
#  145: {'type': 1, 'group': 82, 'transit': inf},
#  146: {'type': 1, 'group': 82, 'transit': inf},
#  147: {'type': 0, 'group': 83, 'transit': inf},
#  148: {'type': 1, 'group': 83, 'transit': inf},
#  149: {'type': 1, 'group': 83, 'transit': inf},
#  150: {'type': 1, 'group': 84, 'transit': inf},
#  151: {'type': 1, 'group': 84, 'transit': inf},
#  152: {'type': 1, 'group': 85, 'transit': inf},
#  153: {'type': 1, 'group': 85, 'transit': inf},
#  154: {'type': 0, 'group': 86, 'transit': inf},
#  155: {'type': 2, 'group': 86, 'transit': inf},
#  156: {'type': 0, 'group': 87, 'transit': inf},
#  157: {'type': 0, 'group': 88, 'transit': inf},
#  158: {'type': 0, 'group': 88, 'transit': inf},
#  159: {'type': 1, 'group': 88, 'transit': inf},
#  160: {'type': 0, 'group': 89, 'transit': inf},
#  161: {'type': 0, 'group': 89, 'transit': inf},
#  162: {'type': 1, 'group': 89, 'transit': inf}}

# %% [markdown]
# We define a dictionnary *Groups*, containing as keys the ids of groups with more than two passengers and as values, the list of the members of the group

# %%
Groups = dict()


for i, passager in Passengers.items():

    if passager['group'] in Groups:
        Groups[passager['group']].append(i)
    else :
        Groups[passager['group']] = [i]

Keys = list(Groups.keys()).copy()


for i in Keys:
        if len(Groups[i]) ==1: del(Groups[i])
Groups
# Out:
# {4: [4, 5],
#  6: [7, 8],
#  8: [10, 11, 12, 13, 14],
#  9: [15, 16, 17, 18],
#  11: [20, 21],
#  12: [22, 23, 24, 25, 26],
#  13: [27, 28, 29, 30],
#  14: [31, 32, 33, 34, 35],
#  17: [38, 39],
#  18: [40, 41, 42, 43, 44],
#  20: [46, 47],
#  23: [50, 51, 52],
#  24: [53, 54, 55, 56],
#  26: [58, 59, 60],
#  27: [61, 62],
#  36: [71, 72],
#  38: [74, 75, 76],
#  39: [77, 78],
#  41: [80, 81],
#  42: [82, 83],
#  46: [87, 88, 89, 90, 91],
#  51: [96, 97],
#  57: [103, 104, 105, 106],
#  60: [109, 110],
#  65: [115, 116, 117, 118],
#  67: [120, 121],
#  73: [127, 128],
#  74: [129, 130, 131],
#  75: [132, 133, 134],
#  76: [135, 136],
#  79: [139, 140],
#  81: [142, 143],
#  82: [144, 145, 146],
#  83: [147, 148, 149],
#  84: [150, 151],
#  85: [152, 153],
#  86: [154, 155],
#  88: [157, 158, 159],
#  89: [160, 161, 162]}

# %% [markdown]
# Definition of parameters necessary for the following steps

# %%
weight_f = 70
weight_m = 85
weight_d = 92.5

if sum([4*number_d,number_f,number_m]) <= 174 :
    number_of_rows = 29 #modèle d'avion A320
else :
    number_of_rows = 35 #modèle d'avion A321

number_of_columns = 7 # ajout de la colonne qui correspond à l'allée

# %% [markdown]
# ## Model

# %% [markdown]
# Defining the relevant variables of the problem

# %% [markdown]
# The binary variables $AssignmentVarDict[(i,j,k)]$ specify whether the seat located at position $(i,j)$ is occupied by passenger $k$.

# %%
m = Model("Seats_Allocation")

AssignmenVarDict = {(i, j, k) : m.addVar(vtype = GRB.BINARY, name=f'x_{i}_{j}_{k}')
                    for i in range(1, number_of_rows + 1)
                    for j in range(1, number_of_columns + 1)
                    for k in range(1, len(Passengers)+1)}
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-06

# %% [markdown]
# ### Les contraintes

# %% [markdown]
# - Every person has one seat

# %%
PERSONSEATCONSTDIC = { k: m.addConstr(quicksum([AssignmenVarDict[(i, j, k)]
                                                for i in range(1, number_of_rows + 1)
                                                for j in range(1, number_of_columns + 1) ])
                                                == 1)
                                                for k in range(1,len(Passengers)+1) }

# %% [markdown]
# - Every seat is allocated to a single person

# %%
ALLOCATIONCONSTDIC = { (i,j) : m.addConstr(quicksum([AssignmenVarDict[(i,j,k)]
                                                     for k in range(1, len(Passengers)+1)])
                                                     <=1)
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in range(1, number_of_columns+1) }

# %% [markdown]
# - Aisle seats are always free

# %%
AISLECONSTDIC = { i : m.addConstr(quicksum([AssignmenVarDict[(i,4,k)]
                                                     for k in range(1, len(Passengers)+1)])
                                                     == 0)
                                                     for i in range(1, number_of_rows + 1)   
}

# %% [markdown]
# - Barycenter constraint

# %%
i_m = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==1])

i_f = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==0])

i_d = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==2])

i_bary = (i_m + i_f +i_d)/( weight_d* number_d + weight_f * number_f + weight_m * number_m)

j_m = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==1])

j_f = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==0])

j_d = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==2])

j_bary = (j_m + j_f + j_d)/( weight_d* number_d + weight_f * number_f + weight_m * number_m)

# %%
IMAXBARYCONST = m.addConstr(i_bary <= 17)
IMINBARYCONST = m.addConstr(13 <= i_bary)
JMAXBARYCONST = m.addConstr(j_bary <= 5)
JMINBARYCONST = m.addConstr(3 <= j_bary )

# %% [markdown]
# - A disabeled person has 4 seats on the aisle side

# %%
SeatPer_WCHR_CONST = {k: m.addConstr(quicksum([AssignmenVarDict[(i, j, k)] 
                                               for i in range(1, number_of_rows ) 
                                               for j in [3, 6] 
                                               ]) == 1, name=f"SeatPerWCHR{k}")
                                               for k in range(1, len(Passengers) + 1)
                                               if Passengers[k]['type'] == 2}

for k in range(1, len(Passengers) + 1):
    if Passengers[k]['type'] == 2:
        for i in range(1, number_of_rows):
            for j in [3, 6]:
                m.addConstr(AssignmenVarDict[(i, j, k)] + quicksum(
                      [AssignmenVarDict[(i, j - 1, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1, 
                            name=f'Neighbor_WCHR{k}_{i}_{j-1}')
                
                m.addConstr(AssignmenVarDict[(i, j, k)] +quicksum(
                      [AssignmenVarDict[(i+1, j, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1, 
                            name=f'Neighbor_WCHR{k}_{i+1}_{j}')
                m.addConstr(AssignmenVarDict[(i, j, k)]+ quicksum(
                      [AssignmenVarDict[(i+1, j - 1, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1,  
                            name=f'Neighbor_WCHR{k}_{i+1}_{j-1}')

# %% [markdown]
# ## Objectif Time

# %% [markdown]
# - Transit time

# %%
transit_obj = quicksum( [ AssignmenVarDict[(i,j,k)]* i*(1/Passengers[k]['transit'])
                      for i in range(1, number_of_rows+1)
                      for j in range(1, number_of_columns+1 )
                      for k in range(1, len(Passengers)+1)
                      if Passengers[k]['transit'] != float('inf') ])

m.setObjective(transit_obj, GRB.MINIMIZE)

m.params.outputflag = 0 

m.update()

# %% [markdown]
# ## Optimisation

# %%
m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
#                                                    z* = 2.63

# %%
z_old = round(transit_obj.getValue(), 2) #saving this value for later

# %% [markdown]
# - Transit time visualization

# %%
def generate_blue_gradations(num_gradations):
    gradations = []
    for i in range(num_gradations):
         # Linearly decrease the green component from full (255) to 0
        green_intensity = int(255 * (1 - i / (num_gradations - 1)))
        # Keep the red component at full intensity
        red_intensity = 255
        # Combine the components into a color value
        color_value = f"#{red_intensity:02X}{green_intensity:02X}00"
        gradations.append(color_value)
    return gradations
graduation = generate_blue_gradations(len(transit_times))
transit_times = list(transit_times)
transit_times.sort()
color_transit = dict()
for i in range(len(transit_times)):
    color_transit[transit_times[i]] = graduation[-i-1]

# %%
data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['transit']!=float('inf'): colors1[i-1][j-1] = color_transit[Passengers[k]['transit']]
                elif j > 4 :
                    data2[i-1][j-5] = k
                    if Passengers[k]['transit']!=float('inf'): colors2[i-1][j-5] = color_transit[Passengers[k]['transit']]

# %%
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - Disabled visualization

# %%
data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['type']==2 :
                        colors1[i-1][j-1] = '#800080'
                        colors1[i-1][j-2] = '#800080'
                        colors1[i][j-1] = '#800080'
                        colors1[i][j-2] = '#800080'
                elif j>4:
                    data2[i-1][j-5] = k
                    if Passengers[k]['type']==2:
                        colors2[i-1][j-5] = '#800080'
                        colors2[i-1][j-6] = '#800080'
                        colors2[i][j-5] = '#800080'
                        colors2[i][j-6] = '#800080'

# %%
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# ## Objectif Grouping

# %% [markdown]
# **Fonction objective : ObjGrouping1**

# %% [markdown]
# The binary variables $AssignmentVarGrpDict[(g,i,j, m, n)]$ specify whether the seats located at positions $(i,j)$ and $(i,j+1)$ are occupied by passengers $m$ and $n$ from the group $g$ resp.

# %%
AssignmenVarGrpDict= { (g , i, j , Groups[g][k], Groups[g][l]) : m.addVar(vtype = GRB.BINARY, name=f'Y_{i}_{j}_{Groups[g][k]}_{Groups[g][l]}')
                    for i in range(1, number_of_rows + 1)
                    for j in range(1, number_of_columns)
                    for g in Groups.keys()
                    for k in range(len(Groups[g]))
                    for l in range(len(Groups[g]))

                    }

# %% [markdown]
# Defining some contraints to ensure the definition of the variables $AssignmentVarGrpDict[(g,i,j,m,n)]$

# %%
GroupingConstDict1 = { g : m.addConstr( AssignmenVarGrpDict[(g,i,j,Groups[g][k],Groups[g][l])] <= AssignmenVarDict[(i,j,Groups[g][k])])
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in range(1, number_of_columns)
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                                                     }

GroupingConstDict2 = { g : m.addConstr( AssignmenVarGrpDict[(g,i,j,Groups[g][k],Groups[g][l])] <= AssignmenVarDict[(i,j+1,Groups[g][l])])
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in [1,2,5,6]
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                                                     }
GroupingAisleConstDict2 = { g : m.addConstr( AssignmenVarGrpDict[(g,i,3,Groups[g][k],Groups[g][l])] <= AssignmenVarDict[(i,5,Groups[g][l])])
                                                     for i in range(1, number_of_rows + 1)
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                                                     }

GroupingConstDict3 = { g : m.addConstr( AssignmenVarGrpDict[(g,i,j,Groups[g][k],Groups[g][l])] >= 
                                       AssignmenVarDict[(i,j+1,Groups[g][l])] + AssignmenVarDict[(i,j,Groups[g][k])] -1)
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in [1,2,5,6]
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                                                     }
GroupingAisleConstDict3 = { g : m.addConstr( AssignmenVarGrpDict[(g,i,3,Groups[g][k],Groups[g][l])] >= 
                                       AssignmenVarDict[(i,5,Groups[g][l])] + AssignmenVarDict[(i,3,Groups[g][k])] -1)
                                                     for i in range(1, number_of_rows + 1)
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                                                     }

obj_grouping = quicksum([AssignmenVarGrpDict[(g, i , j, Groups[g][k], Groups[g][l])]
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in [1,2,5,6]
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                         ])

obj_grouping_aisle = quicksum([AssignmenVarGrpDict[(g, i , 3, Groups[g][k], Groups[g][l])]
                                                     for i in range(1, number_of_rows + 1)
                                                     for g in Groups.keys()
                                                     for k in range(len(Groups[g]))
                                                     for l in range(len(Groups[g]))
                         ])
m.setObjective(2*obj_grouping + obj_grouping_aisle, GRB.MAXIMIZE)

# %%
m.params.outputflag = 1

m.update()
# Out:
# Set parameter OutputFlag to value 1

# %%
num_vars = m.NumVars
num_vars
# Out:
# 116550

# %% [markdown]
# ## Optimisation

# %%
# Set iteration limit
m.setParam(GRB.Param.TimeLimit, 900)  # Change to the desired iterationTime limit

m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
# Set parameter TimeLimit to value 900
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 207251 rows, 116550 columns and 1017660 nonzeros
# Model fingerprint: 0x38f2649e
# Variable types: 0 continuous, 116550 integer (116550 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# MIP start from previous solve produced solution with objective 5 (0.09s)
# Loaded MIP start from previous solve with objective 5
#
# Presolve removed 84001 rows and 23220 columns (presolve time = 5s) ...
# Presolve removed 122189 rows and 42314 columns
# Presolve time: 7.64s
# Presolved: 85062 rows, 74236 columns, 615616 nonzeros
# Variable types: 0 continuous, 74236 integer (74236 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.562e+04
#  Factor NZ  : 8.511e+04 (roughly 3 MB of memory)
#  Factor Ops : 2.874e+06 (less than 1 second per iteration)
#  Threads    : 10
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.94345542e+05  1.88316929e+05  1.45e+04 3.08e+00  1.38e+03     8s
#    1   2.52766826e+05  1.44775778e+05  4.29e+03 1.71e-13  3.64e+02     8s
#    2   2.91505715e+04  1.04444172e+05  3.65e+02 1.28e-13  3.86e+01     8s
#    3   4.16784291e+03  1.97281194e+04  5.10e+01 1.07e-13  5.45e+00     8s
#    4   8.00193117e+02  7.12863078e+03  7.39e+00 8.97e-14  1.16e+00     8s
#    5   3.06705764e+02  1.68781671e+03  5.26e-01 8.54e-14  1.71e-01     8s
#    6   3.23894450e+02  6.89986487e+02  5.22e-02 5.26e-14  4.12e-02     8s
#    7   3.48328405e+02  3.85628134e+02  4.40e-03 3.44e-14  4.16e-03     8s
#    8   3.58718147e+02  3.75469210e+02  8.15e-04 3.43e-14  1.85e-03     8s
#    9   3.63233548e+02  3.64971632e+02  1.36e-05 3.46e-14  1.91e-04     8s
#   10   3.63996692e+02  3.64004054e+02  5.26e-13 3.51e-14  8.08e-07     8s
#   11   3.63999997e+02  3.64000004e+02  4.83e-13 3.21e-14  8.08e-10     8s
#   12   3.64000000e+02  3.64000000e+02  3.84e-13 3.73e-14  9.02e-16     8s
#
# Barrier solved model in 12 iterations and 8.01 seconds (9.39 work units)
# Optimal objective 3.64000000e+02
#
#
# Root crossover log...
#
#     1042 DPushes remaining with DInf 0.0000000e+00                 8s
#        0 DPushes remaining with DInf 0.0000000e+00                 8s
#
#      511 PPushes remaining with PInf 0.0000000e+00                 8s
#        0 PPushes remaining with PInf 0.0000000e+00                 8s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.4695805e-13      8s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1382    3.6400000e+02   0.000000e+00   0.000000e+00      8s
# Concurrent spin time: 0.03s
#
# Solved with barrier
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 8s
#
#     4169 PPushes remaining with PInf 0.0000000e+00                 8s
#        0 PPushes remaining with PInf 0.0000000e+00                 9s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      9s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    26865    3.6400000e+02   0.000000e+00   0.000000e+00      9s
#    26865    3.6400000e+02   0.000000e+00   0.000000e+00      9s
#
# Root relaxation: objective 3.640000e+02, 26865 iterations, 0.87 seconds (1.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  364.00000    0 2935    5.00000  364.00000  7180%     -   17s
# H    0     0                      63.0000000  364.00000   478%     -   20s
#      0     0  364.00000    0 3185   63.00000  364.00000   478%     -   40s
# H    0     0                     130.0000000  364.00000   180%     -   55s
#      0     0  361.32222    0 2626  130.00000  361.32222   178%     -   69s
#      0     0  361.22222    0 2972  130.00000  361.22222   178%     -   96s
#      0     0  355.95859    0 2937  130.00000  355.95859   174%     -  125s
#      0     0  355.95859    0 2739  130.00000  355.95859   174%     -  129s
#      0     0  352.66354    0 2767  130.00000  352.66354   171%     -  153s
# H    0     0                     133.0000000  352.66354   165%     -  171s
#      0     0  344.21737    0 2809  133.00000  344.21737   159%     -  199s
#      0     0  344.18542    0 2934  133.00000  344.18542   159%     -  210s
#      0     0  344.18542    0 2852  133.00000  344.18542   159%     -  213s
#      0     0  341.87172    0 3201  133.00000  341.87172   157%     -  235s
#      0     0          -    0       133.00000  341.87172   157%     -  918s
#
# Cutting planes:
#   Gomory: 77
#   Implied bound: 18
#   Clique: 41
#   MIR: 6
#   Zero half: 470
#   RLT: 4673
#   BQP: 10030
#
# Explored 1 nodes (179879 simplex iterations) in 918.90 seconds (396.73 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 133 130 63 5
#
# Time limit reached
# Best objective 1.330000000000e+02, best bound 3.410000000000e+02, gap 156.3910%
#                                                    z* = 133.0

# %% [markdown]
# - Grouping Visualisation

# %%
def generate_random_colors(num_colors):
    colors = []
    for _ in range(num_colors):

        red = random.randint(0, 255)
        green = random.randint(0, 255)
        blue = random.randint(0, 255)

        color_value = "#{:02X}{:02X}{:02X}".format(red, green, blue)
        colors.append(color_value)
    return colors

graduation = generate_random_colors(len(Groups))
indices_groups = list(Groups.keys())
color_group = {indices_groups[i-1] : graduation[i-1] for i in range(1, len(Groups)+1) }

# %%
data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['group']in color_group: colors1[i-1][j-1] = color_group[Passengers[k]['group']]
                else:
                    data2[i-1][j-5] = k
                    if Passengers[k]['group'] in color_group: colors2[i-1][j-5] = color_group[Passengers[k]['group']]

# %%
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %%
## Coupling both objectives

# %%
m.setObjective(- 0.7*obj_grouping + 0.3*transit_obj, GRB.MINIMIZE)

m.params.outputflag = 1

m.update()

# %% [markdown]
# ## Optimisation

# %%
# Set iteration limit
m.setParam(GRB.Param.TimeLimit, 900)  # Change to the desired iterationTime limit

m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 12 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 207251 rows, 116550 columns and 1017660 nonzeros
# Model fingerprint: 0x2cf53b1f
# Variable types: 0 continuous, 116550 integer (116550 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 1e+00]
#   Objective range  [4e-03, 7e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start from previous solve with objective -40.196
#
# Presolve removed 108345 rows and 35392 columns (presolve time = 22s) ...
# Presolve removed 139113 rows and 50776 columns
# Presolve time: 22.51s
# Presolved: 68138 rows, 65774 columns, 581768 nonzeros
# Variable types: 0 continuous, 65774 integer (65774 binary)
# Found heuristic solution: objective -40.2338182
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 5.834e+04
#  Factor NZ  : 1.105e+05 (roughly 5 MB of memory)
#  Factor Ops : 3.472e+06 (less than 1 second per iteration)
#  Threads    : 10
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.89249679e+05 -5.44932192e+04  8.42e+03 1.46e+00  1.67e+02    23s
#    1  -6.62786239e+04 -4.11560054e+04  3.59e+03 2.84e-14  6.63e+01    23s
#    2  -1.06870928e+04 -2.95766609e+04  4.41e+02 7.11e-14  9.30e+00    23s
#    3  -1.56106751e+03 -1.89156100e+04  5.53e+01 8.88e-14  2.19e+00    23s
#    4  -6.52340770e+02 -1.89424190e+03  2.19e+01 4.26e-14  3.79e-01    23s
#    5  -5.52063596e+02 -1.49711311e+03  1.81e+01 3.20e-14  2.94e-01    23s
#    6  -1.07752728e+02 -6.70384318e+02  9.01e-01 1.95e-14  4.86e-02    23s
#    7  -9.44613277e+01 -2.43435852e+02  3.18e-03 1.20e-14  1.06e-02    23s
#    8  -1.04853498e+02 -1.25400674e+02  2.82e-05 8.26e-15  1.46e-03    23s
#    9  -1.09991284e+02 -1.17578732e+02  1.03e-06 8.52e-15  5.39e-04    23s
#   10  -1.11707138e+02 -1.14732551e+02  2.03e-07 7.61e-15  2.15e-04    23s
#   11  -1.12140945e+02 -1.13867144e+02  1.25e-07 8.01e-15  1.23e-04    23s
#   12  -1.12454403e+02 -1.13580482e+02  8.03e-08 6.23e-15  8.00e-05    23s
#   13  -1.12584672e+02 -1.13431691e+02  6.41e-08 6.26e-15  6.01e-05    23s
#   14  -1.12882185e+02 -1.13331047e+02  2.87e-08 7.16e-15  3.19e-05    23s
#   15  -1.13024764e+02 -1.13245980e+02  1.37e-08 7.34e-15  1.57e-05    23s
#   16  -1.13107671e+02 -1.13195896e+02  5.39e-09 7.15e-15  6.26e-06    23s
#   17  -1.13142697e+02 -1.13176436e+02  2.02e-09 6.79e-15  2.40e-06    23s
#   18  -1.13157660e+02 -1.13170074e+02  6.50e-10 7.78e-15  8.81e-07    23s
#   19  -1.13162689e+02 -1.13166972e+02  2.09e-10 6.95e-15  3.04e-07    23s
#   20  -1.13164657e+02 -1.13165635e+02  4.37e-11 6.50e-15  6.94e-08    23s
#   21  -1.13165154e+02 -1.13165196e+02  4.73e-12 8.45e-15  2.99e-09    23s
#   22  -1.13165186e+02 -1.13165186e+02  2.07e-12 7.90e-15  2.99e-12    23s
#
# Barrier solved model in 22 iterations and 23.04 seconds (19.91 work units)
# Optimal objective -1.13165186e+02
#
#
# Root crossover log...
#
#     2378 DPushes remaining with DInf 0.0000000e+00                23s
#        0 DPushes remaining with DInf 0.0000000e+00                23s
#
#      492 PPushes remaining with PInf 0.0000000e+00                23s
#        0 PPushes remaining with PInf 0.0000000e+00                23s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.9200908e-14     23s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2740   -1.1316519e+02   0.000000e+00   0.000000e+00     23s
# Concurrent spin time: 0.04s
#
# Solved with barrier
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                24s
#
#     2341 PPushes remaining with PInf 0.0000000e+00                24s
#        0 PPushes remaining with PInf 0.0000000e+00                24s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 7.6745207e-13     24s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    21329   -1.1316519e+02   0.000000e+00   0.000000e+00     24s
#    21329   -1.1316519e+02   0.000000e+00   0.000000e+00     24s
#
# Root relaxation: objective -1.131652e+02, 21329 iterations, 1.04 seconds (0.81 work units)
# Total elapsed time = 32.39s (DegenMoves)
# Total elapsed time = 37.05s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -113.16519    0 1548  -40.23382 -113.16519   181%     -   41s
# H    0     0                     -40.7745455 -113.16519   178%     -   42s
#      0     0 -110.51647    0 1653  -40.77455 -110.51647   171%     -   54s
# H    0     0                     -42.3981818 -110.51647   161%     -   86s
#      0     0 -109.52559    0 1530  -42.39818 -109.52559   158%     -   95s
#      0     0 -109.48530    0 1559  -42.39818 -109.48530   158%     -  101s
#      0     0 -109.43621    0 1443  -42.39818 -109.43621   158%     -  104s
#      0     0 -109.38712    0 1561  -42.39818 -109.38712   158%     -  109s
#      0     0 -109.33803    0 1661  -42.39818 -109.33803   158%     -  111s
#      0     0 -109.28894    0 1545  -42.39818 -109.28894   158%     -  115s
#      0     0 -109.23985    0 1437  -42.39818 -109.23985   158%     -  118s
#      0     0 -109.19076    0 1555  -42.39818 -109.19076   158%     -  120s
#      0     0 -108.92176    0 1653  -42.39818 -108.92176   157%     -  125s
#      0     0 -108.91915    0 1471  -42.39818 -108.91915   157%     -  129s
#      0     0 -108.91708    0 1474  -42.39818 -108.91708   157%     -  134s
#      0     0 -108.91708    0 1379  -42.39818 -108.91708   157%     -  137s
#      0     0 -108.17279    0 1460  -42.39818 -108.17279   155%     -  366s
# H    0     0                     -42.4036364 -108.17279   155%     -  367s
#      0     0 -108.16388    0 1469  -42.40364 -108.16388   155%     -  368s
#      0     0 -108.04795    0 1546  -42.40364 -108.04795   155%     -  371s
#      0     0 -108.04770    0 1729  -42.40364 -108.04770   155%     -  373s
#      0     0 -107.96769    0 1692  -42.40364 -107.96769   155%     -  378s
# H    0     0                     -42.4970909 -107.96769   154%     -  390s
#      0     0 -107.96685    0 1498  -42.49709 -107.96685   154%     -  392s
#      0     0 -107.86769    0 1702  -42.49709 -107.86769   154%     -  396s
#      0     0 -107.86747    0 1656  -42.49709 -107.86747   154%     -  400s
#      0     0 -107.75134    0 1348  -42.49709 -107.75134   154%     -  406s
#      0     0 -107.75134    0 1260  -42.49709 -107.75134   154%     -  407s
#      0     0 -107.65723    0 1402  -42.49709 -107.65723   153%     -  411s
# H    0     0                     -42.4970913 -107.65723   153%     -  415s
#      0     0 -107.65723    0 1362  -42.49709 -107.65723   153%     -  420s
#      0     0 -107.55394    0 1413  -42.49709 -107.55394   153%     -  428s
#      0     0 -107.55394    0 1324  -42.49709 -107.55394   153%     -  432s
#      0     0 -107.46267    0 1583  -42.49709 -107.46267   153%     -  442s
# H    0     0                     -42.5000000 -107.46267   153%     -  468s
#      0     0 -107.46267    0 1529  -42.50000 -107.46267   153%     -  469s
#      0     0 -107.37692    0 1458  -42.50000 -107.37692   153%     -  478s
#      0     0 -107.37692    0 1447  -42.50000 -107.37692   153%     -  479s
#      0     0 -107.28739    0 1449  -42.50000 -107.28739   152%     -  486s
#      0     0 -107.28739    0 1573  -42.50000 -107.28739   152%     -  490s
#      0     0 -107.19925    0 1479  -42.50000 -107.19925   152%     -  501s
#      0     0 -107.19781    0 1494  -42.50000 -107.19781   152%     -  506s
#      0     0 -106.97992    0 1453  -42.50000 -106.97992   152%     -  527s
#      0     0 -106.96577    0 1402  -42.50000 -106.96577   152%     -  533s
#      0     0 -106.96551    0 1398  -42.50000 -106.96551   152%     -  533s
#      0     0 -106.15823    0 1429  -42.50000 -106.15823   150%     -  544s
# H    0     0                     -42.5054545 -106.15823   150%     -  564s
#      0     0 -106.13769    0 1467  -42.50545 -106.13769   150%     -  569s
#      0     0 -106.13591    0 1429  -42.50545 -106.13591   150%     -  571s
#      0     0 -106.03501    0 1385  -42.50545 -106.03501   149%     -  582s
#      0     0 -106.02420    0 1442  -42.50545 -106.02420   149%     -  587s
#      0     0 -106.02010    0 1513  -42.50545 -106.02010   149%     -  591s
#      0     0 -105.96022    0 1477  -42.50545 -105.96022   149%     -  604s
#      0     0 -105.95609    0 1359  -42.50545 -105.95609   149%     -  609s
#      0     0 -105.77913    0 1576  -42.50545 -105.77913   149%     -  626s
#      0     0 -105.76866    0 1553  -42.50545 -105.76866   149%     -  632s
#      0     0 -105.76858    0 1496  -42.50545 -105.76858   149%     -  633s
#      0     0 -105.58510    0 1605  -42.50545 -105.58510   148%     -  650s
#      0     0 -105.57754    0 1457  -42.50545 -105.57754   148%     -  653s
#      0     0 -105.57715    0 1427  -42.50545 -105.57715   148%     -  654s
#      0     0 -105.24423    0 1695  -42.50545 -105.24423   148%     -  668s
#      0     0 -105.23161    0 1443  -42.50545 -105.23161   148%     -  672s
#      0     0 -105.22642    0 1535  -42.50545 -105.22642   148%     -  673s
#      0     0 -104.50193    0 1651  -42.50545 -104.50193   146%     -  683s
# H    0     0                     -42.5083636 -104.50193   146%     -  693s
#      0     0 -104.46367    0 1638  -42.50836 -104.46367   146%     -  697s
#      0     0 -104.44590    0 1547  -42.50836 -104.44590   146%     -  700s
#      0     0 -104.40467    0 1628  -42.50836 -104.40467   146%     -  703s
#      0     0 -104.40467    0 1644  -42.50836 -104.40467   146%     -  704s
#      0     0 -103.88556    0 1713  -42.50836 -103.88556   144%     -  713s
#      0     0 -103.87700    0 1679  -42.50836 -103.87700   144%     -  715s
#      0     0 -103.17552    0 1590  -42.50836 -103.17552   143%     -  724s
#      0     0 -103.04548    0 1513  -42.50836 -103.04548   142%     -  732s
#      0     0 -102.98211    0 1623  -42.50836 -102.98211   142%     -  737s
#      0     0 -102.98211    0 1623  -42.50836 -102.98211   142%     -  737s
#      0     0 -102.31038    0 1590  -42.50836 -102.31038   141%     -  747s
#      0     0 -102.23909    0 1560  -42.50836 -102.23909   141%     -  751s
#      0     0 -102.20500    0 1593  -42.50836 -102.20500   140%     -  753s
#      0     0 -102.20500    0 1653  -42.50836 -102.20500   140%     -  753s
#      0     0 -101.38083    0 1621  -42.50836 -101.38083   138%     -  769s
# H    0     0                     -42.5083640 -101.38083   138%     -  783s
#      0     0 -101.34028    0 1753  -42.50836 -101.34028   138%     -  784s
#      0     0 -101.34028    0 1734  -42.50836 -101.34028   138%     -  784s
#      0     0  -98.04357    0 1552  -42.50836  -98.04357   131%     -  835s
#      0     0  -97.79375    0 1563  -42.50836  -97.79375   130%     -  840s
#      0     0  -97.79057    0 1579  -42.50836  -97.79057   130%     -  841s
#      0     0  -93.54567    0 1420  -42.50836  -93.54567   120%     -  853s
#      0     0  -93.37587    0 1592  -42.50836  -93.37587   120%     -  865s
#      0     0  -93.33826    0 1671  -42.50836  -93.33826   120%     -  870s
#      0     0  -93.33817    0 1645  -42.50836  -93.33817   120%     -  871s
#      0     0          -    0       -42.50836  -93.33817   120%     -  900s
#
# Cutting planes:
#   Gomory: 600
#   Lift-and-project: 6
#   Implied bound: 36
#   Clique: 101
#   MIR: 3
#   Flow cover: 1
#   Zero half: 2061
#   RLT: 16216
#   Relax-and-lift: 6
#   BQP: 33879
#
# Explored 1 nodes (394495 simplex iterations) in 900.04 seconds (894.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: -42.5084 -42.5084 -42.5055 ... -40.2338
#
# Time limit reached
# Best objective -4.250836401280e+01, best bound -9.333816879130e+01, gap 119.5760%
#                                                   z* = -42.51

# %% [markdown]
# - Transit time visualisation

# %%
def generate_blue_gradations(num_gradations):
    gradations = []
    for i in range(num_gradations):
         # Linearly decrease the green component from full (255) to 0
        green_intensity = int(255 * (1 - i / (num_gradations - 1)))
        # Keep the red component at full intensity
        red_intensity = 255
        # Combine the components into a color value
        color_value = f"#{red_intensity:02X}{green_intensity:02X}00"
        gradations.append(color_value)
    return gradations
graduation = generate_blue_gradations(len(transit_times))
transit_times = list(transit_times)
transit_times.sort()
color_transit = dict()
for i in range(len(transit_times)):
    color_transit[transit_times[i]] = graduation[-i-1]

data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['transit']!=float('inf'): colors1[i-1][j-1] = color_transit[Passengers[k]['transit']]
                elif j > 4 :
                    data2[i-1][j-5] = k
                    if Passengers[k]['transit']!=float('inf'): colors2[i-1][j-5] = color_transit[Passengers[k]['transit']]


def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - Disabled visualization

# %%
data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['type']==2 :
                        colors1[i-1][j-1] = '#800080'
                        colors1[i-1][j-2] = '#800080'
                        colors1[i][j-1] = '#800080'
                        colors1[i][j-2] = '#800080'
                elif j>4:
                    data2[i-1][j-5] = k
                    if Passengers[k]['type']==2:
                        colors2[i-1][j-5] = '#800080'
                        colors2[i-1][j-6] = '#800080'
                        colors2[i][j-5] = '#800080'
                        colors2[i][j-6] = '#800080'

def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - Groups vizualisation

# %%
def generate_random_colors(num_colors):
    colors = []
    for _ in range(num_colors):

        red = random.randint(0, 255)
        green = random.randint(0, 255)
        blue = random.randint(0, 255)

        color_value = "#{:02X}{:02X}{:02X}".format(red, green, blue)
        colors.append(color_value)
    return colors

graduation = generate_random_colors(len(Groups))
indices_groups = list(Groups.keys())
color_group = {indices_groups[i-1] : graduation[i-1] for i in range(1, len(Groups)+1) }


data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = f"{k} g{Passengers[k]['group']}"
                    if Passengers[k]['group']in color_group: colors1[i-1][j-1] = color_group[Passengers[k]['group']]
                else:
                    data2[i-1][j-5] = f"{k} g{Passengers[k]['group']}"
                    if Passengers[k]['group'] in color_group: colors2[i-1][j-5] = color_group[Passengers[k]['group']]

                    
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()
