# %% [markdown]
# # <font color=blue><div align="center">Seats Allocation within an Aircraft</div></font>
#
# ### <font color=blue><div align="center">29-02-2024</div></font>

# %% [markdown]
# ## Modules

# %%
# Basic modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.table import Table
import random

# Gurobi module
from gurobipy import *

# %% [markdown]
# ## Data Extraction

# %%
# Load the Excel file into a pandas DataFrame


df_21Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=0 , skipfooter=2)
df_22Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=1 , skipfooter=2)
df_23Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=2 , skipfooter=2)
df_24Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=3 , skipfooter=2)
df_30Oct = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=4 , skipfooter=2)
df_05Nov = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=5 , skipfooter=2)
df_07Nov = pd.read_excel('./ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=6 , skipfooter=2)

# %%
# Display the DataFrame
df = df_07Nov
df
# Out:
#     Numéro du groupe  Femmes  Hommes  WCHR TransitTime
# 0                  1     1.0     NaN   NaN    00:55:00
# 1                  2     NaN     1.0   NaN    00:00:00
# 2                  3     1.0     NaN   NaN    01:15:00
# 3                  4     1.0     1.0   NaN    03:15:00
# 4                  5     1.0     NaN   NaN    00:00:00
# ..               ...     ...     ...   ...         ...
# 84                85     NaN     2.0   NaN    00:00:00
# 85                86     1.0     NaN   1.0    00:00:00
# 86                87     1.0     NaN   NaN    03:15:00
# 87                88     2.0     1.0   NaN    00:00:00
# 88                89     2.0     1.0   NaN    00:00:00
#
# [89 rows x 5 columns]

# %% [markdown]
# The code in the cells below creates a dictionary Passengers defined as follows:
#
# - Passengers Keys: IDs of passengers.
# - Passengers Items: For each ID in Passengers, we specify its *type* (female: 0, male: 1, disabled: 2), its *group number*, and its *transit time*.
#
# Notice that for passengers with a transit time equal to 0 or larger than 2 hours, the transit time in the dictionary is set to $\infty$

# %%
def convert_TransitTime(time_val):

    # Convert time to minutes
    total_minutes = time_val.hour * 60 + time_val.minute
    
    # Check if total minutes is greater than 2 hours or equal to 0
    if total_minutes > 120 or total_minutes == 0:
        return float('inf')  # Return infinity
    else:
        return total_minutes

df['TransitTime'] = df['TransitTime'].apply(convert_TransitTime)

# %%
# Create Passengers dictionary
Passengers = dict()
i = 1

number_f = 0
number_m = 0
number_d = 0

transit_times = set()

# Groups : dict[int : List[int]]

Passengers = dict()
i = 1

for group in df.itertuples():
    if not pd.isna(group[2]):
        for k in range(int(group[2])):
            Passengers[i] = {'type': 0, 'group':group[1], 'transit':group[5]}
            number_f += 1
            transit_times.add(group[5])
            i+=1
    if not pd.isna(group[3]):
        for k in range(int(group[3])):
            Passengers[i] = {'type': 1, 'group':group[1], 'transit':group[5]}
            number_m += 1
            transit_times.add(group[5])
            i+=1
    if not pd.isna(group[4]):
        for k in range(int(group[4])):
            Passengers[i] = {'type': 2, 'group':group[1], 'transit':group[5]}
            number_d += 1
            transit_times.add(group[5])
            i+=1
    
    
Passengers
# Out:
# {1: {'type': 0, 'group': 1, 'transit': 55.0},
#  2: {'type': 1, 'group': 2, 'transit': inf},
#  3: {'type': 0, 'group': 3, 'transit': 75.0},
#  4: {'type': 0, 'group': 4, 'transit': inf},
#  5: {'type': 1, 'group': 4, 'transit': inf},
#  6: {'type': 0, 'group': 5, 'transit': inf},
#  7: {'type': 0, 'group': 6, 'transit': inf},
#  8: {'type': 0, 'group': 6, 'transit': inf},
#  9: {'type': 2, 'group': 7, 'transit': inf},
#  10: {'type': 0, 'group': 8, 'transit': inf},
#  11: {'type': 1, 'group': 8, 'transit': inf},
#  12: {'type': 1, 'group': 8, 'transit': inf},
#  13: {'type': 1, 'group': 8, 'transit': inf},
#  14: {'type': 1, 'group': 8, 'transit': inf},
#  15: {'type': 0, 'group': 9, 'transit': inf},
#  16: {'type': 0, 'group': 9, 'transit': inf},
#  17: {'type': 0, 'group': 9, 'transit': inf},
#  18: {'type': 0, 'group': 9, 'transit': inf},
#  19: {'type': 0, 'group': 10, 'transit': inf},
#  20: {'type': 0, 'group': 11, 'transit': inf},
#  21: {'type': 1, 'group': 11, 'transit': inf},
#  22: {'type': 0, 'group': 12, 'transit': inf},
#  23: {'type': 0, 'group': 12, 'transit': inf},
#  24: {'type': 0, 'group': 12, 'transit': inf},
#  25: {'type': 0, 'group': 12, 'transit': inf},
#  26: {'type': 0, 'group': 12, 'transit': inf},
#  27: {'type': 0, 'group': 13, 'transit': 75.0},
#  28: {'type': 0, 'group': 13, 'transit': 75.0},
#  29: {'type': 2, 'group': 13, 'transit': 75.0},
#  30: {'type': 2, 'group': 13, 'transit': 75.0},
#  31: {'type': 0, 'group': 14, 'transit': 55.0},
#  32: {'type': 0, 'group': 14, 'transit': 55.0},
#  33: {'type': 0, 'group': 14, 'transit': 55.0},
#  34: {'type': 0, 'group': 14, 'transit': 55.0},
#  35: {'type': 1, 'group': 14, 'transit': 55.0},
#  36: {'type': 0, 'group': 15, 'transit': inf},
#  37: {'type': 2, 'group': 16, 'transit': 55.0},
#  38: {'type': 0, 'group': 17, 'transit': inf},
#  39: {'type': 1, 'group': 17, 'transit': inf},
#  40: {'type': 0, 'group': 18, 'transit': 75.0},
#  41: {'type': 0, 'group': 18, 'transit': 75.0},
#  42: {'type': 0, 'group': 18, 'transit': 75.0},
#  43: {'type': 0, 'group': 18, 'transit': 75.0},
#  44: {'type': 0, 'group': 18, 'transit': 75.0},
#  45: {'type': 0, 'group': 19, 'transit': inf},
#  46: {'type': 0, 'group': 20, 'transit': 75.0},
#  47: {'type': 0, 'group': 20, 'transit': 75.0},
#  48: {'type': 2, 'group': 21, 'transit': inf},
#  49: {'type': 0, 'group': 22, 'transit': inf},
#  50: {'type': 0, 'group': 23, 'transit': inf},
#  51: {'type': 1, 'group': 23, 'transit': inf},
#  52: {'type': 1, 'group': 23, 'transit': inf},
#  53: {'type': 0, 'group': 24, 'transit': 75.0},
#  54: {'type': 0, 'group': 24, 'transit': 75.0},
#  55: {'type': 0, 'group': 24, 'transit': 75.0},
#  56: {'type': 0, 'group': 24, 'transit': 75.0},
#  57: {'type': 0, 'group': 25, 'transit': inf},
#  58: {'type': 1, 'group': 26, 'transit': 55.0},
#  59: {'type': 2, 'group': 26, 'transit': 55.0},
#  60: {'type': 2, 'group': 26, 'transit': 55.0},
#  61: {'type': 0, 'group': 27, 'transit': inf},
#  62: {'type': 1, 'group': 27, 'transit': inf},
#  63: {'type': 1, 'group': 28, 'transit': inf},
#  64: {'type': 1, 'group': 29, 'transit': inf},
#  65: {'type': 1, 'group': 30, 'transit': inf},
#  66: {'type': 0, 'group': 31, 'transit': inf},
#  67: {'type': 0, 'group': 32, 'transit': inf},
#  68: {'type': 1, 'group': 33, 'transit': 55.0},
#  69: {'type': 1, 'group': 34, 'transit': inf},
#  70: {'type': 0, 'group': 35, 'transit': inf},
#  71: {'type': 0, 'group': 36, 'transit': 55.0},
#  72: {'type': 1, 'group': 36, 'transit': 55.0},
#  73: {'type': 0, 'group': 37, 'transit': inf},
#  74: {'type': 0, 'group': 38, 'transit': inf},
#  75: {'type': 0, 'group': 38, 'transit': inf},
#  76: {'type': 1, 'group': 38, 'transit': inf},
#  77: {'type': 0, 'group': 39, 'transit': inf},
#  78: {'type': 1, 'group': 39, 'transit': inf},
#  79: {'type': 1, 'group': 40, 'transit': inf},
#  80: {'type': 1, 'group': 41, 'transit': inf},
#  81: {'type': 1, 'group': 41, 'transit': inf},
#  82: {'type': 0, 'group': 42, 'transit': 55.0},
#  83: {'type': 1, 'group': 42, 'transit': 55.0},
#  84: {'type': 1, 'group': 43, 'transit': 75.0},
#  85: {'type': 1, 'group': 44, 'transit': inf},
#  86: {'type': 1, 'group': 45, 'transit': inf},
#  87: {'type': 0, 'group': 46, 'transit': inf},
#  88: {'type': 0, 'group': 46, 'transit': inf},
#  89: {'type': 0, 'group': 46, 'transit': inf},
#  90: {'type': 0, 'group': 46, 'transit': inf},
#  91: {'type': 0, 'group': 46, 'transit': inf},
#  92: {'type': 0, 'group': 47, 'transit': inf},
#  93: {'type': 1, 'group': 48, 'transit': inf},
#  94: {'type': 1, 'group': 49, 'transit': inf},
#  95: {'type': 1, 'group': 50, 'transit': inf},
#  96: {'type': 1, 'group': 51, 'transit': inf},
#  97: {'type': 2, 'group': 51, 'transit': inf},
#  98: {'type': 0, 'group': 52, 'transit': inf},
#  99: {'type': 0, 'group': 53, 'transit': inf},
#  100: {'type': 1, 'group': 54, 'transit': inf},
#  101: {'type': 1, 'group': 55, 'transit': inf},
#  102: {'type': 1, 'group': 56, 'transit': inf},
#  103: {'type': 0, 'group': 57, 'transit': inf},
#  104: {'type': 0, 'group': 57, 'transit': inf},
#  105: {'type': 1, 'group': 57, 'transit': inf},
#  106: {'type': 1, 'group': 57, 'transit': inf},
#  107: {'type': 1, 'group': 58, 'transit': inf},
#  108: {'type': 1, 'group': 59, 'transit': inf},
#  109: {'type': 1, 'group': 60, 'transit': inf},
#  110: {'type': 1, 'group': 60, 'transit': inf},
#  111: {'type': 1, 'group': 61, 'transit': inf},
#  112: {'type': 0, 'group': 62, 'transit': inf},
#  113: {'type': 1, 'group': 63, 'transit': 75.0},
#  114: {'type': 1, 'group': 64, 'transit': 55.0},
#  115: {'type': 0, 'group': 65, 'transit': inf},
#  116: {'type': 0, 'group': 65, 'transit': inf},
#  117: {'type': 1, 'group': 65, 'transit': inf},
#  118: {'type': 1, 'group': 65, 'transit': inf},
#  119: {'type': 0, 'group': 66, 'transit': inf},
#  120: {'type': 0, 'group': 67, 'transit': inf},
#  121: {'type': 1, 'group': 67, 'transit': inf},
#  122: {'type': 1, 'group': 68, 'transit': inf},
#  123: {'type': 1, 'group': 69, 'transit': inf},
#  124: {'type': 1, 'group': 70, 'transit': inf},
#  125: {'type': 0, 'group': 71, 'transit': inf},
#  126: {'type': 1, 'group': 72, 'transit': 55.0},
#  127: {'type': 0, 'group': 73, 'transit': 75.0},
#  128: {'type': 1, 'group': 73, 'transit': 75.0},
#  129: {'type': 0, 'group': 74, 'transit': inf},
#  130: {'type': 0, 'group': 74, 'transit': inf},
#  131: {'type': 1, 'group': 74, 'transit': inf},
#  132: {'type': 0, 'group': 75, 'transit': inf},
#  133: {'type': 0, 'group': 75, 'transit': inf},
#  134: {'type': 1, 'group': 75, 'transit': inf},
#  135: {'type': 0, 'group': 76, 'transit': inf},
#  136: {'type': 1, 'group': 76, 'transit': inf},
#  137: {'type': 1, 'group': 77, 'transit': inf},
#  138: {'type': 1, 'group': 78, 'transit': inf},
#  139: {'type': 1, 'group': 79, 'transit': inf},
#  140: {'type': 1, 'group': 79, 'transit': inf},
#  141: {'type': 1, 'group': 80, 'transit': 75.0},
#  142: {'type': 0, 'group': 81, 'transit': 55.0},
#  143: {'type': 1, 'group': 81, 'transit': 55.0},
#  144: {'type': 0, 'group': 82, 'transit': inf},
#  145: {'type': 1, 'group': 82, 'transit': inf},
#  146: {'type': 1, 'group': 82, 'transit': inf},
#  147: {'type': 0, 'group': 83, 'transit': inf},
#  148: {'type': 1, 'group': 83, 'transit': inf},
#  149: {'type': 1, 'group': 83, 'transit': inf},
#  150: {'type': 1, 'group': 84, 'transit': inf},
#  151: {'type': 1, 'group': 84, 'transit': inf},
#  152: {'type': 1, 'group': 85, 'transit': inf},
#  153: {'type': 1, 'group': 85, 'transit': inf},
#  154: {'type': 0, 'group': 86, 'transit': inf},
#  155: {'type': 2, 'group': 86, 'transit': inf},
#  156: {'type': 0, 'group': 87, 'transit': inf},
#  157: {'type': 0, 'group': 88, 'transit': inf},
#  158: {'type': 0, 'group': 88, 'transit': inf},
#  159: {'type': 1, 'group': 88, 'transit': inf},
#  160: {'type': 0, 'group': 89, 'transit': inf},
#  161: {'type': 0, 'group': 89, 'transit': inf},
#  162: {'type': 1, 'group': 89, 'transit': inf}}

# %% [markdown]
# We define a dictionnary *Groups*, containing as keys the group ID and as valuea, the list of the members of the group

# %%
Groups = dict()


for i, passager in Passengers.items():

    if passager['group'] in Groups:
        Groups[passager['group']].append(i)
    else :
        Groups[passager['group']] = [i]

Keys = list(Groups.keys()).copy()


for i in Keys:
        if len(Groups[i]) ==1: del(Groups[i])
Groups
# Out:
# {4: [4, 5],
#  6: [7, 8],
#  8: [10, 11, 12, 13, 14],
#  9: [15, 16, 17, 18],
#  11: [20, 21],
#  12: [22, 23, 24, 25, 26],
#  13: [27, 28, 29, 30],
#  14: [31, 32, 33, 34, 35],
#  17: [38, 39],
#  18: [40, 41, 42, 43, 44],
#  20: [46, 47],
#  23: [50, 51, 52],
#  24: [53, 54, 55, 56],
#  26: [58, 59, 60],
#  27: [61, 62],
#  36: [71, 72],
#  38: [74, 75, 76],
#  39: [77, 78],
#  41: [80, 81],
#  42: [82, 83],
#  46: [87, 88, 89, 90, 91],
#  51: [96, 97],
#  57: [103, 104, 105, 106],
#  60: [109, 110],
#  65: [115, 116, 117, 118],
#  67: [120, 121],
#  73: [127, 128],
#  74: [129, 130, 131],
#  75: [132, 133, 134],
#  76: [135, 136],
#  79: [139, 140],
#  81: [142, 143],
#  82: [144, 145, 146],
#  83: [147, 148, 149],
#  84: [150, 151],
#  85: [152, 153],
#  86: [154, 155],
#  88: [157, 158, 159],
#  89: [160, 161, 162]}

# %% [markdown]
# Definition of parameters necessary for the following steps

# %%
weight_f = 70
weight_m = 85
weight_d = 92.5

if sum([4*number_d,number_f,number_m]) <= 174 :
    number_of_rows = 29 #Aircraft model A320
else :
    number_of_rows = 35 #Aircraft model A321

number_of_columns = 7 # adding the aisle

# %% [markdown]
# ## Model

# %% [markdown]
# Defining the relevant variables of the problem

# %% [markdown]
# The binary variables $AssignmentVarDict_{i,j,k}$ specify whether the seat located at position $(i,j)$ is occupied by passenger $k$.

# %%
m = Model("Seats_Allocation")

AssignmenVarDict = {(i, j, k) : m.addVar(vtype = GRB.BINARY, name=f'passager_{i}_{j}_{k}')
                    for i in range(1, number_of_rows + 1)
                    for j in range(1, number_of_columns + 1)
                    for k in range(1, len(Passengers)+1)}

# %% [markdown]
# ### The constraints

# %% [markdown]
# - Every person has one seat

# %%
PERSONSEATCONSTDIC = { k: m.addConstr(quicksum([AssignmenVarDict[(i, j, k)]
                                                for i in range(1, number_of_rows + 1)
                                                for j in range(1, number_of_columns + 1) ])
                                                == 1)
                                                for k in range(1,len(Passengers)+1) }

# %% [markdown]
# - Every seat is allocated to a single person

# %%
ALLOCATIONCONSTDIC = { (i,j) : m.addConstr(quicksum([AssignmenVarDict[(i,j,k)]
                                                     for k in range(1, len(Passengers)+1)])
                                                     <=1)
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in range(1, number_of_columns+1) }

# %% [markdown]
# - Aisle seats are always free

# %%
AISLECONSTDIC = { i : m.addConstr(quicksum([AssignmenVarDict[(i,4,k)]
                                                     for k in range(1, len(Passengers)+1)])
                                                     == 0)
                                                     for i in range(1, number_of_rows + 1)   
}

# %% [markdown]
# - Barycenter constraint

# %%
i_m = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==1])

i_f = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==0])

i_d = quicksum([weight_m * i* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==2])

i_bary = (i_m + i_f +i_d)/( weight_d* number_d + weight_f * number_f + weight_m * number_m)

j_m = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==1])

j_f = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==0])

j_d = quicksum([weight_m * j* AssignmenVarDict[(i,j,k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, number_of_columns+1 )
                for k in range(1, len(Passengers)+1)
                if Passengers[k]['type']==2])

j_bary = (j_m + j_f + j_d)/( weight_d* number_d + weight_f * number_f + weight_m * number_m)

# %%
IMAXBARYCONST = m.addConstr(i_bary <= 17)
IMINBARYCONST = m.addConstr(13 <= i_bary)
JMAXBARYCONST = m.addConstr(j_bary <= 5)
JMINBARYCONST = m.addConstr(3 <= j_bary )

# %% [markdown]
# - A disabeled person has 4 seats on the aisle side

# %%
SeatPer_WCHR_CONST = {k: m.addConstr(quicksum([AssignmenVarDict[(i, j, k)] 
                                               for i in range(1, number_of_rows ) 
                                               for j in [3, 6] 
                                               ]) == 1, name=f"SeatPerWCHR{k}")
                                               for k in range(1, len(Passengers) + 1)
                                               if Passengers[k]['type'] == 2}

for k in range(1, len(Passengers) + 1):
    if Passengers[k]['type'] == 2:
        for i in range(1, number_of_rows):
            for j in [3, 6]:
                m.addConstr(AssignmenVarDict[(i, j, k)] + quicksum(
                      [AssignmenVarDict[(i, j - 1, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1, 
                            name=f'Neighbor_WCHR{k}_{i}_{j-1}')
                
                m.addConstr(AssignmenVarDict[(i, j, k)] +quicksum(
                      [AssignmenVarDict[(i+1, j, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1, 
                            name=f'Neighbor_WCHR{k}_{i+1}_{j}')
                m.addConstr(AssignmenVarDict[(i, j, k)]+ quicksum(
                      [AssignmenVarDict[(i+1, j - 1, p)] for p in range(1, len(Passengers)+1)]
                      ) <= 1,  
                            name=f'Neighbor_WCHR{k}_{i+1}_{j-1}')

# %% [markdown]
# ## Time Objectif

# %% [markdown]
# - Transit time

# %%
transit_obj = quicksum( [ AssignmenVarDict[(i,j,k)]* i*(1/Passengers[k]['transit'])
                      for i in range(1, number_of_rows+1)
                      for j in range(1, number_of_columns+1 )
                      for k in range(1, len(Passengers)+1)
                      if Passengers[k]['transit'] != float('inf') ])

m.setObjective(transit_obj, GRB.MINIMIZE)

m.params.outputflag = 0 

m.update()

# %% [markdown]
# ## Optimisation

# %%
m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
#                                                    z* = 2.63

# %%
z_old = round(transit_obj.getValue(), 2)

# %% [markdown]
# - Transit time visualization

# %%
def generate_blue_gradations(num_gradations):
    gradations = []
    for i in range(num_gradations):
         # Linearly decrease the green component from full (255) to 0
        green_intensity = int(255 * (1 - i / (num_gradations - 1)))
        # Keep the red component at full intensity
        red_intensity = 255
        # Combine the components into a color value
        color_value = f"#{red_intensity:02X}{green_intensity:02X}00"
        gradations.append(color_value)
    return gradations
graduation = generate_blue_gradations(len(transit_times))
transit_times = list(transit_times)
transit_times.sort()
color_transit = dict()
for i in range(len(transit_times)):
    color_transit[transit_times[i]] = graduation[-i-1]

data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['transit']!=float('inf'): colors1[i-1][j-1] = color_transit[Passengers[k]['transit']]
                elif j > 4 :
                    data2[i-1][j-5] = k
                    if Passengers[k]['transit']!=float('inf'): colors2[i-1][j-5] = color_transit[Passengers[k]['transit']]


def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# ## Grouping Objectif

# %%
grouping = quicksum([AssignmenVarDict[(i_1, j_1, group[k_1])] * AssignmenVarDict[(i_2, j_2, group[k_2])] * (0.7 * abs(i_1 - i_2) + 0.3 * abs(j_1 - j_2)) \
                     for group in Groups.values() \
                     for k_1 in range(len(group)) \
                     for k_2 in range(k_1 + 1, len(group)) \
                     for i_1 in range(1, number_of_rows + 1) \
                     for j_1 in range(1, number_of_columns + 1) \
                     for i_2 in range(1, number_of_rows + 1) \
                     for j_2 in range(1, number_of_columns + 1)])

m.setObjective(grouping, GRB.MINIMIZE)

m.params.outputflag = 1

m.update()
# Out:
# Set parameter OutputFlag to value 1

# %% [markdown]
# ## Optimisation

# %%
m.setParam(GRB.Param.TimeLimit, 100)  # Change to the desired iteration limit

m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
# Set parameter TimeLimit to value 100
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2291 rows, 39690 columns and 543690 nonzeros
# Model fingerprint: 0xcf8286f8
# Model has 7592060 quadratic objective terms
# Variable types: 0 continuous, 39690 integer (39690 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [6e-01, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start from previous solve with objective 612.1
#
# Presolve removed 70 rows and 6948 columns (presolve time = 5s) ...
# Presolve removed 217 rows and 6948 columns (presolve time = 77s) ...
# Presolve removed 217 rows and 6948 columns
# Presolve time: 76.61s
# Presolved: 2074 rows, 32742 columns, 449640 nonzeros
# Presolved model has 5280606 quadratic objective terms
# Variable types: 0 continuous, 32742 integer (32742 binary)
# Found heuristic solution: objective 609.1000000
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   3.806983e+05     78s
#     2121   -1.2859109e+05   0.000000e+00   7.802644e+04     81s
#     3373   -1.3617775e+05   0.000000e+00   3.658220e+04     86s
#     4283   -1.3869554e+05   0.000000e+00   2.345431e+04     92s
#     4985   -1.3975746e+05   0.000000e+00   1.783868e+04     99s
#
# Root relaxation: time limit, 5120 iterations, 22.46 seconds (26.43 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0       609.10000    0.00000   100%     -  100s
#
# Explored 1 nodes (5120 simplex iterations) in 100.27 seconds (89.81 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 609.1 612.1
#
# Time limit reached
# Best objective 6.091000000000e+02, best bound 0.000000000000e+00, gap 100.0000%
#                                                    z* = 609.1

# %% [markdown]
# - Grouping visualisation

# %%
def generate_random_colors(num_colors):
    colors = []
    for _ in range(num_colors):

        red = random.randint(0, 255)
        green = random.randint(0, 255)
        blue = random.randint(0, 255)

        color_value = "#{:02X}{:02X}{:02X}".format(red, green, blue)
        colors.append(color_value)
    return colors

graduation = generate_random_colors(len(Groups))
indices_groups = list(Groups.keys())
color_group = {indices_groups[i-1] : graduation[i-1] for i in range(1, len(Groups)+1) }


data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['group']in color_group: colors1[i-1][j-1] = color_group[Passengers[k]['group']]
                else:
                    data2[i-1][j-5] = k
                    if Passengers[k]['group'] in color_group: colors2[i-1][j-5] = color_group[Passengers[k]['group']]

                    
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# ## Coupling both objectives

# %%
m.setObjective(0.7*grouping + 0.3*transit_obj, GRB.MINIMIZE)

m.params.outputflag = 1

m.update()

# %% [markdown]
# ## Optimisation

# %%
# Set iteration limit
m.setParam(GRB.Param.TimeLimit, 100)  # Change to the desired iteration limit

m.optimize()
iteration = 1

if m.status == GRB.INF_OR_UNBD:
    m.setParam(GRB.Param.Presolve, 0)
    m.optimize()

if m.status == GRB.INFEASIBLE:
    print(m.display(), "\n\tTHERE IS NO SOLUTION!!!")
elif m.status == GRB.UNBOUNDED:
    print(m.display(), "\n\tNOT BOUNDED!!!")
else:
    print(f'z* = {round(m.objVal, 2)}'.center(8*14))

print()
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-1255U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2291 rows, 39690 columns and 543690 nonzeros
# Model fingerprint: 0x2a346d94
# Model has 7592060 quadratic objective terms
# Variable types: 0 continuous, 39690 integer (39690 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 1e+00]
#   Objective range  [4e-03, 2e-01]
#   QObjective range [4e-01, 4e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
#
# Loaded MIP start from previous solve with objective 427.159
#
# Presolve removed 217 rows and 6948 columns (presolve time = 100s) ...
# Presolve removed 217 rows and 6948 columns
# Presolve time: 99.88s
# Presolved: 2074 rows, 32742 columns, 449640 nonzeros
# Presolved model has 5257938 quadratic objective terms
# Variable types: 0 continuous, 32742 integer (32742 binary)
#
# Explored 0 nodes (0 simplex iterations) in 101.30 seconds (61.26 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 427.159
#
# Time limit reached
# Best objective 4.271590909091e+02, best bound 0.000000000000e+00, gap 100.0000%
#                                                   z* = 427.16

# %% [markdown]
# - Transit time visualisation

# %%
def generate_blue_gradations(num_gradations):
    gradations = []
    for i in range(num_gradations):
         # Linearly decrease the green component from full (255) to 0
        green_intensity = int(255 * (1 - i / (num_gradations - 1)))
        # Keep the red component at full intensity
        red_intensity = 255
        # Combine the components into a color value
        color_value = f"#{red_intensity:02X}{green_intensity:02X}00"
        gradations.append(color_value)
    return gradations
graduation = generate_blue_gradations(len(transit_times))
transit_times = list(transit_times)
transit_times.sort()
color_transit = dict()
for i in range(len(transit_times)):
    color_transit[transit_times[i]] = graduation[-i-1]

data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['transit']!=float('inf'): colors1[i-1][j-1] = color_transit[Passengers[k]['transit']]
                elif j > 4 :
                    data2[i-1][j-5] = k
                    if Passengers[k]['transit']!=float('inf'): colors2[i-1][j-5] = color_transit[Passengers[k]['transit']]


def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - Disabled visualization

# %%
data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passengers[k]['type']==2 :
                        colors1[i-1][j-1] = '#800080'
                        colors1[i-1][j-2] = '#800080'
                        colors1[i][j-1] = '#800080'
                        colors1[i][j-2] = '#800080'
                elif j>4:
                    data2[i-1][j-5] = k
                    if Passengers[k]['type']==2:
                        colors2[i-1][j-5] = '#800080'
                        colors2[i-1][j-6] = '#800080'
                        colors2[i][j-5] = '#800080'
                        colors2[i][j-6] = '#800080'

def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - Groups vizualisation

# %%
def generate_random_colors(num_colors):
    colors = []
    for _ in range(num_colors):

        red = random.randint(0, 255)
        green = random.randint(0, 255)
        blue = random.randint(0, 255)

        color_value = "#{:02X}{:02X}{:02X}".format(red, green, blue)
        colors.append(color_value)
    return colors

graduation = generate_random_colors(len(Groups))
indices_groups = list(Groups.keys())
color_group = {indices_groups[i-1] : graduation[i-1] for i in range(1, len(Groups)+1) }


data1 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(number_of_columns//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, number_of_columns + 1):
        for k in range(1, len(Passengers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = f"{k} g{Passengers[k]['group']}"
                    if Passengers[k]['group']in color_group: colors1[i-1][j-1] = color_group[Passengers[k]['group']]
                else:
                    data2[i-1][j-5] = f"{k} g{Passengers[k]['group']}"
                    if Passengers[k]['group'] in color_group: colors2[i-1][j-5] = color_group[Passengers[k]['group']]

                    
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# ## Metrics

# %% [markdown]
# - Transit metric

# %%
z_new = round(transit_obj.getValue(), 2)


print("The satisfaction level related to transit time:", (1- (z_new- z_old)/z_old) * 100, " %" )
# Out:
# The satisfaction level related to transit time: 100.0  %

# %% [markdown]
# - Grouping metric

# %%
# Définition des constantes pour les niveaux de satisfaction
SATISFIED = 1.0
MEDIUM_SATISFIED = 0.5
NOT_SATISFIED = 0.0

# Initialisation des variables pour les scores de satisfaction
satisfaction_scores = []

for group, passengers in Groups.items():
    print(passengers)
    for pass_id in passengers:
        seat_positions = [(i, j) for i in range(1, number_of_rows+1)
                            for j in range(1, number_of_columns+1)
                            if AssignmenVarDict.get((i, j, pass_id), 0).x == 1]
        if seat_positions:  # Vérifie si la liste n'est pas vide
            seat_position = seat_positions[0]  # Prend le premier élément
            print(f"** Le passager {pass_id} est assis à la position {seat_position}")
        else:
            print(f"Aucun siège trouvé pour le passager {pass_id}. Vérifiez l'indexation et les données.")
            
        i, j = seat_position
        neighbors = [(i, j-1), (i, j+1)]
        satisfaction = 0
        for neighbor in neighbors:
            ni, nj = neighbor
            if 1 <= nj <= number_of_columns:
                if nj == 4 or j == 4:  # S'ils sont séparés par l'allée, attribuez MEDIUM_SATISFIED seulement si dans la même rangée
                    if any(AssignmenVarDict.get((ni, nj, other_pass_id), 0).x == 1 for other_pass_id in passengers if other_pass_id != pass_id):
                        print(f"Pass {pass_id}, Seat {i, j}, Neighbor {neighbor}, Medium")
                        satisfaction = max(satisfaction, MEDIUM_SATISFIED)
                elif nj != 4:
                    if any(AssignmenVarDict.get((ni, nj, other_pass_id), 0).x == 1 for other_pass_id in passengers if (other_pass_id != pass_id and ni == i)):
                        print(f"Pass {pass_id}, Seat {i, j}, Neighbor {neighbor}, True")
                        satisfaction = max(satisfaction, SATISFIED)
                    else :
                        print(f"Pass {pass_id}, Seat {i, j}, Neighbor {neighbor}, False")
                        satisfaction = max(satisfaction, NOT_SATISFIED)
        satisfaction_scores.append(satisfaction)
        print(f"** Passager {pass_id} -- satisfaction {satisfaction}\n")

for pass_id in range(1, len(Passengers) + 1):
    if all(pass_id not in passengers for _, passengers in Groups.items()):
        # Ce passager est seul
        # print(f"Le passager {pass_id} est seul et est automatiquement SATISFIED.")
        satisfaction_scores.append(SATISFIED)

# Calcul du score de groupement moyen (pourcentage de satisfaction)
grouping_score = sum(satisfaction_scores) / len(satisfaction_scores)

# Retourner le score de groupement en pourcentage
grouping_score_percentage = grouping_score * 100
grouping_score_percentage
# Out:
# [4, 5]
# ** Le passager 4 est assis à la position (25, 6)
# Pass 4, Seat (25, 6), Neighbor (25, 5), False
# Pass 4, Seat (25, 6), Neighbor (25, 7), False
# ** Passager 4 -- satisfaction 0
#
# ** Le passager 5 est assis à la position (11, 2)
# Pass 5, Seat (11, 2), Neighbor (11, 1), False
# Pass 5, Seat (11, 2), Neighbor (11, 3), False
# ** Passager 5 -- satisfaction 0
#
# [7, 8]
# ** Le passager 7 est assis à la position (26, 1)
# Pass 7, Seat (26, 1), Neighbor (26, 2), False
# ** Passager 7 -- satisfaction 0
#
# ** Le passager 8 est assis à la position (10, 3)
# Pass 8, Seat (10, 3), Neighbor (10, 2), False
# ** Passager 8 -- satisfaction 0
#
# [10, 11, 12, 13, 14]
# ** Le passager 10 est assis à la position (21, 3)
# Pass 10, Seat (21, 3), Neighbor (21, 2), False
# ** Passager 10 -- satisfaction 0
#
# ** Le passager 11 est assis à la position (18, 1)
# Pass 11, Seat (18, 1), Neighbor (18, 2), False
# ** Passager 11 -- satisfaction 0
#
# ** Le passager 12 est assis à la position (13, 1)
# Pass 12, Seat (13, 1), Neighbor (13, 2), False
# ** Passager 12 -- satisfaction 0
#
# ** Le passager 13 est assis à la position (19, 7)
# Pass 13, Seat (19, 7), Neighbor (19, 6), False
# ** Passager 13 -- satisfaction 0
#
# ** Le passager 14 est assis à la position (9, 7)
# Pass 14, Seat (9, 7), Neighbor (9, 6), False
# ** Passager 14 -- satisfaction 0
#
# [15, 16, 17, 18]
# ** Le passager 15 est assis à la position (20, 2)
# Pass 15, Seat (20, 2), Neighbor (20, 1), False
# Pass 15, Seat (20, 2), Neighbor (20, 3), False
# ** Passager 15 -- satisfaction 0
#
# ** Le passager 16 est assis à la position (23, 1)
# Pass 16, Seat (23, 1), Neighbor (23, 2), False
# ** Passager 16 -- satisfaction 0
#
# ** Le passager 17 est assis à la position (18, 2)
# Pass 17, Seat (18, 2), Neighbor (18, 1), False
# Pass 17, Seat (18, 2), Neighbor (18, 3), False
# ** Passager 17 -- satisfaction 0
#
# ** Le passager 18 est assis à la position (22, 1)
# Pass 18, Seat (22, 1), Neighbor (22, 2), False
# ** Passager 18 -- satisfaction 0
#
# [20, 21]
# ** Le passager 20 est assis à la position (10, 7)
# Pass 20, Seat (10, 7), Neighbor (10, 6), False
# ** Passager 20 -- satisfaction 0
#
# ** Le passager 21 est assis à la position (11, 1)
# Pass 21, Seat (11, 1), Neighbor (11, 2), False
# ** Passager 21 -- satisfaction 0
#
# [22, 23, 24, 25, 26]
# ** Le passager 22 est assis à la position (26, 5)
# Pass 22, Seat (26, 5), Neighbor (26, 6), False
# ** Passager 22 -- satisfaction 0
#
# ** Le passager 23 est assis à la position (27, 5)
# Pass 23, Seat (27, 5), Neighbor (27, 6), False
# ** Passager 23 -- satisfaction 0
#
# ** Le passager 24 est assis à la position (29, 7)
# Pass 24, Seat (29, 7), Neighbor (29, 6), False
# ** Passager 24 -- satisfaction 0
#
# ** Le passager 25 est assis à la position (14, 1)
# Pass 25, Seat (14, 1), Neighbor (14, 2), False
# ** Passager 25 -- satisfaction 0
#
# ** Le passager 26 est assis à la position (11, 7)
# Pass 26, Seat (11, 7), Neighbor (11, 6), False
# ** Passager 26 -- satisfaction 0
#
# [27, 28, 29, 30]
# ** Le passager 27 est assis à la position (5, 5)
# Pass 27, Seat (5, 5), Neighbor (5, 6), False
# ** Passager 27 -- satisfaction 0
#
# ** Le passager 28 est assis à la position (6, 7)
# Pass 28, Seat (6, 7), Neighbor (6, 6), False
# ** Passager 28 -- satisfaction 0
#
# ** Le passager 29 est assis à la position (15, 6)
# Pass 29, Seat (15, 6), Neighbor (15, 5), False
# Pass 29, Seat (15, 6), Neighbor (15, 7), False
# ** Passager 29 -- satisfaction 0
#
# ** Le passager 30 est assis à la position (20, 6)
# Pass 30, Seat (20, 6), Neighbor (20, 5), False
# Pass 30, Seat (20, 6), Neighbor (20, 7), False
# ** Passager 30 -- satisfaction 0
#
# [31, 32, 33, 34, 35]
# ** Le passager 31 est assis à la position (3, 7)
# Pass 31, Seat (3, 7), Neighbor (3, 6), False
# ** Passager 31 -- satisfaction 0
#
# ** Le passager 32 est assis à la position (2, 6)
# Pass 32, Seat (2, 6), Neighbor (2, 5), False
# Pass 32, Seat (2, 6), Neighbor (2, 7), False
# ** Passager 32 -- satisfaction 0
#
# ** Le passager 33 est assis à la position (2, 1)
# Pass 33, Seat (2, 1), Neighbor (2, 2), False
# ** Passager 33 -- satisfaction 0
#
# ** Le passager 34 est assis à la position (1, 2)
# Pass 34, Seat (1, 2), Neighbor (1, 1), False
# Pass 34, Seat (1, 2), Neighbor (1, 3), True
# ** Passager 34 -- satisfaction 1.0
#
# ** Le passager 35 est assis à la position (1, 3)
# Pass 35, Seat (1, 3), Neighbor (1, 2), True
# ** Passager 35 -- satisfaction 1.0
#
# [38, 39]
# ** Le passager 38 est assis à la position (16, 2)
# Pass 38, Seat (16, 2), Neighbor (16, 1), False
# Pass 38, Seat (16, 2), Neighbor (16, 3), False
# ** Passager 38 -- satisfaction 0
#
# ** Le passager 39 est assis à la position (18, 5)
# Pass 39, Seat (18, 5), Neighbor (18, 6), False
# ** Passager 39 -- satisfaction 0
#
# [40, 41, 42, 43, 44]
# ** Le passager 40 est assis à la position (6, 3)
# Pass 40, Seat (6, 3), Neighbor (6, 2), False
# ** Passager 40 -- satisfaction 0
#
# ** Le passager 41 est assis à la position (5, 7)
# Pass 41, Seat (5, 7), Neighbor (5, 6), False
# ** Passager 41 -- satisfaction 0
#
# ** Le passager 42 est assis à la position (5, 2)
# Pass 42, Seat (5, 2), Neighbor (5, 1), False
# Pass 42, Seat (5, 2), Neighbor (5, 3), False
# ** Passager 42 -- satisfaction 0
#
# ** Le passager 43 est assis à la position (3, 6)
# Pass 43, Seat (3, 6), Neighbor (3, 5), False
# Pass 43, Seat (3, 6), Neighbor (3, 7), False
# ** Passager 43 -- satisfaction 0
#
# ** Le passager 44 est assis à la position (4, 7)
# Pass 44, Seat (4, 7), Neighbor (4, 6), False
# ** Passager 44 -- satisfaction 0
#
# [46, 47]
# ** Le passager 46 est assis à la position (5, 1)
# Pass 46, Seat (5, 1), Neighbor (5, 2), False
# ** Passager 46 -- satisfaction 0
#
# ** Le passager 47 est assis à la position (6, 6)
# Pass 47, Seat (6, 6), Neighbor (6, 5), False
# Pass 47, Seat (6, 6), Neighbor (6, 7), False
# ** Passager 47 -- satisfaction 0
#
# [50, 51, 52]
# ** Le passager 50 est assis à la position (14, 6)
# Pass 50, Seat (14, 6), Neighbor (14, 5), False
# Pass 50, Seat (14, 6), Neighbor (14, 7), False
# ** Passager 50 -- satisfaction 0
#
# ** Le passager 51 est assis à la position (24, 2)
# Pass 51, Seat (24, 2), Neighbor (24, 1), False
# Pass 51, Seat (24, 2), Neighbor (24, 3), False
# ** Passager 51 -- satisfaction 0
#
# ** Le passager 52 est assis à la position (19, 2)
# Pass 52, Seat (19, 2), Neighbor (19, 1), False
# Pass 52, Seat (19, 2), Neighbor (19, 3), False
# ** Passager 52 -- satisfaction 0
#
# [53, 54, 55, 56]
# ** Le passager 53 est assis à la position (4, 6)
# Pass 53, Seat (4, 6), Neighbor (4, 5), False
# Pass 53, Seat (4, 6), Neighbor (4, 7), False
# ** Passager 53 -- satisfaction 0
#
# ** Le passager 54 est assis à la position (4, 2)
# Pass 54, Seat (4, 2), Neighbor (4, 1), False
# Pass 54, Seat (4, 2), Neighbor (4, 3), False
# ** Passager 54 -- satisfaction 0
#
# ** Le passager 55 est assis à la position (5, 3)
# Pass 55, Seat (5, 3), Neighbor (5, 2), False
# ** Passager 55 -- satisfaction 0
#
# ** Le passager 56 est assis à la position (3, 1)
# Pass 56, Seat (3, 1), Neighbor (3, 2), False
# ** Passager 56 -- satisfaction 0
#
# [58, 59, 60]
# ** Le passager 58 est assis à la position (3, 2)
# Pass 58, Seat (3, 2), Neighbor (3, 1), False
# Pass 58, Seat (3, 2), Neighbor (3, 3), False
# ** Passager 58 -- satisfaction 0
#
# ** Le passager 59 est assis à la position (7, 3)
# Pass 59, Seat (7, 3), Neighbor (7, 2), False
# ** Passager 59 -- satisfaction 0
#
# ** Le passager 60 est assis à la position (9, 6)
# Pass 60, Seat (9, 6), Neighbor (9, 5), False
# Pass 60, Seat (9, 6), Neighbor (9, 7), False
# ** Passager 60 -- satisfaction 0
#
# [61, 62]
# ** Le passager 61 est assis à la position (24, 7)
# Pass 61, Seat (24, 7), Neighbor (24, 6), False
# ** Passager 61 -- satisfaction 0
#
# ** Le passager 62 est assis à la position (12, 2)
# Pass 62, Seat (12, 2), Neighbor (12, 1), False
# Pass 62, Seat (12, 2), Neighbor (12, 3), False
# ** Passager 62 -- satisfaction 0
#
# [71, 72]
# ** Le passager 71 est assis à la position (2, 7)
# Pass 71, Seat (2, 7), Neighbor (2, 6), False
# ** Passager 71 -- satisfaction 0
#
# ** Le passager 72 est assis à la position (2, 5)
# Pass 72, Seat (2, 5), Neighbor (2, 6), False
# ** Passager 72 -- satisfaction 0
#
# [74, 75, 76]
# ** Le passager 74 est assis à la position (8, 1)
# Pass 74, Seat (8, 1), Neighbor (8, 2), False
# ** Passager 74 -- satisfaction 0
#
# ** Le passager 75 est assis à la position (23, 7)
# Pass 75, Seat (23, 7), Neighbor (23, 6), False
# ** Passager 75 -- satisfaction 0
#
# ** Le passager 76 est assis à la position (14, 2)
# Pass 76, Seat (14, 2), Neighbor (14, 1), False
# Pass 76, Seat (14, 2), Neighbor (14, 3), False
# ** Passager 76 -- satisfaction 0
#
# [77, 78]
# ** Le passager 77 est assis à la position (11, 5)
# Pass 77, Seat (11, 5), Neighbor (11, 6), False
# ** Passager 77 -- satisfaction 0
#
# ** Le passager 78 est assis à la position (10, 1)
# Pass 78, Seat (10, 1), Neighbor (10, 2), False
# ** Passager 78 -- satisfaction 0
#
# [80, 81]
# ** Le passager 80 est assis à la position (25, 3)
# Pass 80, Seat (25, 3), Neighbor (25, 2), False
# ** Passager 80 -- satisfaction 0
#
# ** Le passager 81 est assis à la position (28, 5)
# Pass 81, Seat (28, 5), Neighbor (28, 6), False
# ** Passager 81 -- satisfaction 0
#
# [82, 83]
# ** Le passager 82 est assis à la position (3, 3)
# Pass 82, Seat (3, 3), Neighbor (3, 2), False
# ** Passager 82 -- satisfaction 0
#
# ** Le passager 83 est assis à la position (2, 2)
# Pass 83, Seat (2, 2), Neighbor (2, 1), False
# Pass 83, Seat (2, 2), Neighbor (2, 3), False
# ** Passager 83 -- satisfaction 0
#
# [87, 88, 89, 90, 91]
# ** Le passager 87 est assis à la position (16, 1)
# Pass 87, Seat (16, 1), Neighbor (16, 2), False
# ** Passager 87 -- satisfaction 0
#
# ** Le passager 88 est assis à la position (19, 6)
# Pass 88, Seat (19, 6), Neighbor (19, 5), False
# Pass 88, Seat (19, 6), Neighbor (19, 7), False
# ** Passager 88 -- satisfaction 0
#
# ** Le passager 89 est assis à la position (28, 1)
# Pass 89, Seat (28, 1), Neighbor (28, 2), False
# ** Passager 89 -- satisfaction 0
#
# ** Le passager 90 est assis à la position (28, 3)
# Pass 90, Seat (28, 3), Neighbor (28, 2), False
# ** Passager 90 -- satisfaction 0
#
# ** Le passager 91 est assis à la position (30, 1)
# Pass 91, Seat (30, 1), Neighbor (30, 2), False
# ** Passager 91 -- satisfaction 0
#
# [96, 97]
# ** Le passager 96 est assis à la position (26, 3)
# Pass 96, Seat (26, 3), Neighbor (26, 2), False
# ** Passager 96 -- satisfaction 0
#
# ** Le passager 97 est assis à la position (30, 3)
# Pass 97, Seat (30, 3), Neighbor (30, 2), False
# ** Passager 97 -- satisfaction 0
#
# [103, 104, 105, 106]
# ** Le passager 103 est assis à la position (29, 3)
# Pass 103, Seat (29, 3), Neighbor (29, 2), False
# ** Passager 103 -- satisfaction 0
#
# ** Le passager 104 est assis à la position (19, 5)
# Pass 104, Seat (19, 5), Neighbor (19, 6), False
# ** Passager 104 -- satisfaction 0
#
# ** Le passager 105 est assis à la position (19, 3)
# Pass 105, Seat (19, 3), Neighbor (19, 2), False
# ** Passager 105 -- satisfaction 0
#
# ** Le passager 106 est assis à la position (21, 7)
# Pass 106, Seat (21, 7), Neighbor (21, 6), False
# ** Passager 106 -- satisfaction 0
#
# [109, 110]
# ** Le passager 109 est assis à la position (27, 6)
# Pass 109, Seat (27, 6), Neighbor (27, 5), False
# Pass 109, Seat (27, 6), Neighbor (27, 7), False
# ** Passager 109 -- satisfaction 0
#
# ** Le passager 110 est assis à la position (7, 1)
# Pass 110, Seat (7, 1), Neighbor (7, 2), False
# ** Passager 110 -- satisfaction 0
#
# [115, 116, 117, 118]
# ** Le passager 115 est assis à la position (20, 7)
# Pass 115, Seat (20, 7), Neighbor (20, 6), False
# ** Passager 115 -- satisfaction 0
#
# ** Le passager 116 est assis à la position (25, 1)
# Pass 116, Seat (25, 1), Neighbor (25, 2), False
# ** Passager 116 -- satisfaction 0
#
# ** Le passager 117 est assis à la position (29, 2)
# Pass 117, Seat (29, 2), Neighbor (29, 1), False
# Pass 117, Seat (29, 2), Neighbor (29, 3), False
# ** Passager 117 -- satisfaction 0
#
# ** Le passager 118 est assis à la position (11, 3)
# Pass 118, Seat (11, 3), Neighbor (11, 2), False
# ** Passager 118 -- satisfaction 0
#
# [120, 121]
# ** Le passager 120 est assis à la position (7, 7)
# Pass 120, Seat (7, 7), Neighbor (7, 6), False
# ** Passager 120 -- satisfaction 0
#
# ** Le passager 121 est assis à la position (27, 7)
# Pass 121, Seat (27, 7), Neighbor (27, 6), False
# ** Passager 121 -- satisfaction 0
#
# [127, 128]
# ** Le passager 127 est assis à la position (4, 1)
# Pass 127, Seat (4, 1), Neighbor (4, 2), False
# ** Passager 127 -- satisfaction 0
#
# ** Le passager 128 est assis à la position (6, 2)
# Pass 128, Seat (6, 2), Neighbor (6, 1), False
# Pass 128, Seat (6, 2), Neighbor (6, 3), False
# ** Passager 128 -- satisfaction 0
#
# [129, 130, 131]
# ** Le passager 129 est assis à la position (9, 2)
# Pass 129, Seat (9, 2), Neighbor (9, 1), False
# Pass 129, Seat (9, 2), Neighbor (9, 3), True
# ** Passager 129 -- satisfaction 1.0
#
# ** Le passager 130 est assis à la position (13, 6)
# Pass 130, Seat (13, 6), Neighbor (13, 5), False
# Pass 130, Seat (13, 6), Neighbor (13, 7), False
# ** Passager 130 -- satisfaction 0
#
# ** Le passager 131 est assis à la position (9, 3)
# Pass 131, Seat (9, 3), Neighbor (9, 2), True
# ** Passager 131 -- satisfaction 1.0
#
# [132, 133, 134]
# ** Le passager 132 est assis à la position (27, 1)
# Pass 132, Seat (27, 1), Neighbor (27, 2), False
# ** Passager 132 -- satisfaction 0
#
# ** Le passager 133 est assis à la position (22, 3)
# Pass 133, Seat (22, 3), Neighbor (22, 2), False
# ** Passager 133 -- satisfaction 0
#
# ** Le passager 134 est assis à la position (24, 5)
# Pass 134, Seat (24, 5), Neighbor (24, 6), False
# ** Passager 134 -- satisfaction 0
#
# [135, 136]
# ** Le passager 135 est assis à la position (6, 1)
# Pass 135, Seat (6, 1), Neighbor (6, 2), False
# ** Passager 135 -- satisfaction 0
#
# ** Le passager 136 est assis à la position (15, 7)
# Pass 136, Seat (15, 7), Neighbor (15, 6), False
# ** Passager 136 -- satisfaction 0
#
# [139, 140]
# ** Le passager 139 est assis à la position (19, 1)
# Pass 139, Seat (19, 1), Neighbor (19, 2), False
# ** Passager 139 -- satisfaction 0
#
# ** Le passager 140 est assis à la position (18, 7)
# Pass 140, Seat (18, 7), Neighbor (18, 6), False
# ** Passager 140 -- satisfaction 0
#
# [142, 143]
# ** Le passager 142 est assis à la position (1, 1)
# Pass 142, Seat (1, 1), Neighbor (1, 2), False
# ** Passager 142 -- satisfaction 0
#
# ** Le passager 143 est assis à la position (1, 6)
# Pass 143, Seat (1, 6), Neighbor (1, 5), False
# Pass 143, Seat (1, 6), Neighbor (1, 7), False
# ** Passager 143 -- satisfaction 0
#
# [144, 145, 146]
# ** Le passager 144 est assis à la position (28, 2)
# Pass 144, Seat (28, 2), Neighbor (28, 1), False
# Pass 144, Seat (28, 2), Neighbor (28, 3), False
# ** Passager 144 -- satisfaction 0
#
# ** Le passager 145 est assis à la position (17, 3)
# Pass 145, Seat (17, 3), Neighbor (17, 2), False
# ** Passager 145 -- satisfaction 0
#
# ** Le passager 146 est assis à la position (25, 7)
# Pass 146, Seat (25, 7), Neighbor (25, 6), False
# ** Passager 146 -- satisfaction 0
#
# [147, 148, 149]
# ** Le passager 147 est assis à la position (22, 5)
# Pass 147, Seat (22, 5), Neighbor (22, 6), False
# ** Passager 147 -- satisfaction 0
#
# ** Le passager 148 est assis à la position (17, 7)
# Pass 148, Seat (17, 7), Neighbor (17, 6), False
# ** Passager 148 -- satisfaction 0
#
# ** Le passager 149 est assis à la position (18, 3)
# Pass 149, Seat (18, 3), Neighbor (18, 2), False
# ** Passager 149 -- satisfaction 0
#
# [150, 151]
# ** Le passager 150 est assis à la position (21, 1)
# Pass 150, Seat (21, 1), Neighbor (21, 2), False
# ** Passager 150 -- satisfaction 0
#
# ** Le passager 151 est assis à la position (8, 7)
# Pass 151, Seat (8, 7), Neighbor (8, 6), False
# ** Passager 151 -- satisfaction 0
#
# [152, 153]
# ** Le passager 152 est assis à la position (12, 7)
# Pass 152, Seat (12, 7), Neighbor (12, 6), False
# ** Passager 152 -- satisfaction 0
#
# ** Le passager 153 est assis à la position (24, 6)
# Pass 153, Seat (24, 6), Neighbor (24, 5), False
# Pass 153, Seat (24, 6), Neighbor (24, 7), False
# ** Passager 153 -- satisfaction 0
#
# [154, 155]
# ** Le passager 154 est assis à la position (24, 3)
# Pass 154, Seat (24, 3), Neighbor (24, 2), False
# ** Passager 154 -- satisfaction 0
#
# ** Le passager 155 est assis à la position (31, 6)
# Pass 155, Seat (31, 6), Neighbor (31, 5), False
# Pass 155, Seat (31, 6), Neighbor (31, 7), False
# ** Passager 155 -- satisfaction 0
#
# [157, 158, 159]
# ** Le passager 157 est assis à la position (28, 6)
# Pass 157, Seat (28, 6), Neighbor (28, 5), False
# Pass 157, Seat (28, 6), Neighbor (28, 7), False
# ** Passager 157 -- satisfaction 0
#
# ** Le passager 158 est assis à la position (13, 3)
# Pass 158, Seat (13, 3), Neighbor (13, 2), False
# ** Passager 158 -- satisfaction 0
#
# ** Le passager 159 est assis à la position (24, 1)
# Pass 159, Seat (24, 1), Neighbor (24, 2), False
# ** Passager 159 -- satisfaction 0
#
# [160, 161, 162]
# ** Le passager 160 est assis à la position (18, 6)
# Pass 160, Seat (18, 6), Neighbor (18, 5), False
# Pass 160, Seat (18, 6), Neighbor (18, 7), False
# ** Passager 160 -- satisfaction 0
#
# ** Le passager 161 est assis à la position (22, 7)
# Pass 161, Seat (22, 7), Neighbor (22, 6), False
# ** Passager 161 -- satisfaction 0
#
# ** Le passager 162 est assis à la position (14, 7)
# Pass 162, Seat (14, 7), Neighbor (14, 6), False
# ** Passager 162 -- satisfaction 0
# 33.33333333333333
