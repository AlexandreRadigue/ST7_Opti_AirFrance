# %% [markdown]
# # <font color=blue><div align="center">Seats Allocation within an Aircraft</div></font>

# %% [markdown]
# Ouissal, Salima, Alexandre, Idriss, Elias

# %% [markdown]
# ## Modules

# %%
# Modules de base
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.table import Table
import pandas as pd
import random
# %matplotlib inline

# Module relatif à Gurobi
from gurobipy import *

# Module csv
import csv

# %% [markdown]
# ## Préprocessing des données

# %% [markdown]
# Pour la suite de notre étude, on considère le modèle d'avion **Airbus A320**, qui dispose de **174** sièges. (La classe businees n'est pas prise en compte)

# %% [markdown]
# <img src="modele_avion.jpg" alt="Modèle de l'avion" width="400" height="600">

# %%
# Load the Excel file into a pandas DataFrame

df_21Oct = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=0 , skipfooter=2)
df_22Oct = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=1 , skipfooter=2)
df_23Oct = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=2 , skipfooter=2)
df_24Oct = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=3 , skipfooter=2)
df_30Oct = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=4 , skipfooter=2)
df_05Nov = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=5 , skipfooter=2)
df_07Nov = pd.read_excel('../ST7 - AirFrance/DataSeating 2024.xlsx', sheet_name=6 , skipfooter=2)

# %%
# On choisit la df sur laquelle on va travailler

df = df_21Oct
# df = df_22Oct
# df = df_23Oct
# df = df_24Oct
# df = df_30Oct
# df = df_05Nov
# df = df_07Nov

# %%
# Groups : dict[int : List[int]]

Passagers = dict()
i = 1

number_f = 0
number_m = 0
number_d = 0
transit_times= set()
for group in df.itertuples():
    for j in range(2,5):
        if not pd.isna(group[j]):
            for k in range(int(group[j])):
                transit_time = group[5].hour*60 + group[5].minute
                Passagers[i] = {'gender': j-2, 'group': group[1], 'transit': float('inf')}
                if transit_time != 0 and transit_time < 121:
                    Passagers[i]['transit'] = transit_time
                    transit_times.add(transit_time)  # Add to the list, keeping duplicates if any
                if j == 2: number_f+=1
                elif j==3: number_m+=1
                else: number_d+=1

                i+=1    

Passagers
# Out:
# {1: {'gender': 1, 'group': 1, 'transit': 75},
#  2: {'gender': 0, 'group': 2, 'transit': inf},
#  3: {'gender': 1, 'group': 3, 'transit': inf},
#  4: {'gender': 0, 'group': 4, 'transit': inf},
#  5: {'gender': 1, 'group': 5, 'transit': inf},
#  6: {'gender': 1, 'group': 5, 'transit': inf},
#  7: {'gender': 0, 'group': 6, 'transit': inf},
#  8: {'gender': 0, 'group': 7, 'transit': inf},
#  9: {'gender': 0, 'group': 8, 'transit': 80},
#  10: {'gender': 1, 'group': 8, 'transit': 80},
#  11: {'gender': 1, 'group': 9, 'transit': inf},
#  12: {'gender': 0, 'group': 10, 'transit': inf},
#  13: {'gender': 0, 'group': 11, 'transit': inf},
#  14: {'gender': 1, 'group': 11, 'transit': inf},
#  15: {'gender': 1, 'group': 12, 'transit': 70},
#  16: {'gender': 1, 'group': 13, 'transit': inf},
#  17: {'gender': 0, 'group': 14, 'transit': inf},
#  18: {'gender': 1, 'group': 14, 'transit': inf},
#  19: {'gender': 1, 'group': 15, 'transit': inf},
#  20: {'gender': 1, 'group': 16, 'transit': 95},
#  21: {'gender': 0, 'group': 17, 'transit': 60},
#  22: {'gender': 1, 'group': 17, 'transit': 60},
#  23: {'gender': 1, 'group': 18, 'transit': 120},
#  24: {'gender': 0, 'group': 19, 'transit': inf},
#  25: {'gender': 0, 'group': 19, 'transit': inf},
#  26: {'gender': 1, 'group': 19, 'transit': inf},
#  27: {'gender': 1, 'group': 19, 'transit': inf},
#  28: {'gender': 0, 'group': 20, 'transit': 65},
#  29: {'gender': 0, 'group': 20, 'transit': 65},
#  30: {'gender': 1, 'group': 20, 'transit': 65},
#  31: {'gender': 1, 'group': 20, 'transit': 65},
#  32: {'gender': 0, 'group': 21, 'transit': inf},
#  33: {'gender': 0, 'group': 21, 'transit': inf},
#  34: {'gender': 0, 'group': 22, 'transit': 65},
#  35: {'gender': 0, 'group': 23, 'transit': 50},
#  36: {'gender': 1, 'group': 23, 'transit': 50},
#  37: {'gender': 0, 'group': 24, 'transit': inf},
#  38: {'gender': 1, 'group': 24, 'transit': inf},
#  39: {'gender': 1, 'group': 25, 'transit': 80},
#  40: {'gender': 1, 'group': 26, 'transit': inf},
#  41: {'gender': 1, 'group': 27, 'transit': inf},
#  42: {'gender': 1, 'group': 27, 'transit': inf},
#  43: {'gender': 1, 'group': 28, 'transit': inf},
#  44: {'gender': 0, 'group': 29, 'transit': inf},
#  45: {'gender': 1, 'group': 30, 'transit': inf},
#  46: {'gender': 0, 'group': 31, 'transit': 95},
#  47: {'gender': 1, 'group': 31, 'transit': 95},
#  48: {'gender': 1, 'group': 32, 'transit': inf},
#  49: {'gender': 1, 'group': 33, 'transit': inf},
#  50: {'gender': 0, 'group': 34, 'transit': 90},
#  51: {'gender': 1, 'group': 34, 'transit': 90},
#  52: {'gender': 0, 'group': 35, 'transit': 70},
#  53: {'gender': 1, 'group': 35, 'transit': 70},
#  54: {'gender': 0, 'group': 36, 'transit': inf},
#  55: {'gender': 1, 'group': 37, 'transit': inf},
#  56: {'gender': 1, 'group': 38, 'transit': inf},
#  57: {'gender': 0, 'group': 39, 'transit': 95},
#  58: {'gender': 1, 'group': 39, 'transit': 95},
#  59: {'gender': 1, 'group': 40, 'transit': 45},
#  60: {'gender': 1, 'group': 41, 'transit': inf},
#  61: {'gender': 1, 'group': 42, 'transit': inf},
#  62: {'gender': 1, 'group': 43, 'transit': inf},
#  63: {'gender': 1, 'group': 44, 'transit': inf},
#  64: {'gender': 0, 'group': 45, 'transit': inf},
#  65: {'gender': 1, 'group': 45, 'transit': inf},
#  66: {'gender': 1, 'group': 46, 'transit': 80},
#  67: {'gender': 1, 'group': 47, 'transit': 70},
#  68: {'gender': 0, 'group': 48, 'transit': 70},
#  69: {'gender': 1, 'group': 49, 'transit': inf},
#  70: {'gender': 0, 'group': 50, 'transit': inf},
#  71: {'gender': 0, 'group': 51, 'transit': inf},
#  72: {'gender': 1, 'group': 51, 'transit': inf},
#  73: {'gender': 0, 'group': 52, 'transit': 60},
#  74: {'gender': 0, 'group': 53, 'transit': 60},
#  75: {'gender': 0, 'group': 54, 'transit': inf},
#  76: {'gender': 0, 'group': 55, 'transit': inf},
#  77: {'gender': 1, 'group': 55, 'transit': inf},
#  78: {'gender': 0, 'group': 56, 'transit': inf},
#  79: {'gender': 1, 'group': 56, 'transit': inf},
#  80: {'gender': 0, 'group': 57, 'transit': 95},
#  81: {'gender': 1, 'group': 57, 'transit': 95},
#  82: {'gender': 1, 'group': 58, 'transit': inf},
#  83: {'gender': 0, 'group': 59, 'transit': 70},
#  84: {'gender': 1, 'group': 59, 'transit': 70},
#  85: {'gender': 0, 'group': 60, 'transit': 120},
#  86: {'gender': 0, 'group': 61, 'transit': inf},
#  87: {'gender': 1, 'group': 61, 'transit': inf},
#  88: {'gender': 1, 'group': 62, 'transit': inf},
#  89: {'gender': 0, 'group': 63, 'transit': 120},
#  90: {'gender': 1, 'group': 63, 'transit': 120},
#  91: {'gender': 1, 'group': 64, 'transit': inf},
#  92: {'gender': 0, 'group': 65, 'transit': inf},
#  93: {'gender': 0, 'group': 65, 'transit': inf},
#  94: {'gender': 1, 'group': 65, 'transit': inf},
#  95: {'gender': 0, 'group': 66, 'transit': inf},
#  96: {'gender': 1, 'group': 67, 'transit': inf},
#  97: {'gender': 0, 'group': 68, 'transit': inf},
#  98: {'gender': 1, 'group': 68, 'transit': inf},
#  99: {'gender': 1, 'group': 69, 'transit': inf},
#  100: {'gender': 0, 'group': 70, 'transit': inf},
#  101: {'gender': 0, 'group': 71, 'transit': 120},
#  102: {'gender': 1, 'group': 71, 'transit': 120},
#  103: {'gender': 0, 'group': 72, 'transit': inf},
#  104: {'gender': 1, 'group': 73, 'transit': inf},
#  105: {'gender': 1, 'group': 74, 'transit': 65},
#  106: {'gender': 1, 'group': 75, 'transit': 95},
#  107: {'gender': 0, 'group': 76, 'transit': 95},
#  108: {'gender': 0, 'group': 77, 'transit': 60},
#  109: {'gender': 1, 'group': 77, 'transit': 60},
#  110: {'gender': 1, 'group': 78, 'transit': inf},
#  111: {'gender': 1, 'group': 79, 'transit': inf},
#  112: {'gender': 1, 'group': 80, 'transit': 100},
#  113: {'gender': 1, 'group': 81, 'transit': 120},
#  114: {'gender': 1, 'group': 82, 'transit': 100},
#  115: {'gender': 1, 'group': 83, 'transit': 100},
#  116: {'gender': 1, 'group': 84, 'transit': 100},
#  117: {'gender': 1, 'group': 85, 'transit': 100},
#  118: {'gender': 1, 'group': 86, 'transit': 70},
#  119: {'gender': 0, 'group': 87, 'transit': 60},
#  120: {'gender': 1, 'group': 87, 'transit': 60},
#  121: {'gender': 0, 'group': 88, 'transit': inf},
#  122: {'gender': 0, 'group': 89, 'transit': 120},
#  123: {'gender': 0, 'group': 90, 'transit': inf},
#  124: {'gender': 1, 'group': 91, 'transit': 60},
#  125: {'gender': 0, 'group': 92, 'transit': inf},
#  126: {'gender': 1, 'group': 92, 'transit': inf},
#  127: {'gender': 1, 'group': 93, 'transit': inf},
#  128: {'gender': 1, 'group': 94, 'transit': inf},
#  129: {'gender': 0, 'group': 95, 'transit': 90},
#  130: {'gender': 1, 'group': 95, 'transit': 90},
#  131: {'gender': 0, 'group': 96, 'transit': inf},
#  132: {'gender': 1, 'group': 97, 'transit': inf},
#  133: {'gender': 1, 'group': 98, 'transit': inf},
#  134: {'gender': 1, 'group': 99, 'transit': inf},
#  135: {'gender': 0, 'group': 100, 'transit': inf},
#  136: {'gender': 0, 'group': 101, 'transit': inf},
#  137: {'gender': 1, 'group': 102, 'transit': 100},
#  138: {'gender': 0, 'group': 103, 'transit': 80},
#  139: {'gender': 1, 'group': 103, 'transit': 80},
#  140: {'gender': 0, 'group': 104, 'transit': inf},
#  141: {'gender': 1, 'group': 104, 'transit': inf},
#  142: {'gender': 0, 'group': 105, 'transit': inf},
#  143: {'gender': 1, 'group': 106, 'transit': inf},
#  144: {'gender': 0, 'group': 107, 'transit': inf},
#  145: {'gender': 0, 'group': 108, 'transit': inf},
#  146: {'gender': 0, 'group': 108, 'transit': inf},
#  147: {'gender': 0, 'group': 109, 'transit': inf},
#  148: {'gender': 0, 'group': 109, 'transit': inf},
#  149: {'gender': 0, 'group': 110, 'transit': 95},
#  150: {'gender': 0, 'group': 110, 'transit': 95},
#  151: {'gender': 1, 'group': 111, 'transit': 60}}

# %%
Groups = dict()

for i, passager in Passagers.items():

    if passager['group'] in Groups:
        Groups[passager['group']].append(i)
    else :
        Groups[passager['group']] = [i]
for i in range(1,len(df)+1):
    if len(Groups[i]) ==1: del(Groups[i])
Groups
# Out:
# {5: [5, 6],
#  8: [9, 10],
#  11: [13, 14],
#  14: [17, 18],
#  17: [21, 22],
#  19: [24, 25, 26, 27],
#  20: [28, 29, 30, 31],
#  21: [32, 33],
#  23: [35, 36],
#  24: [37, 38],
#  27: [41, 42],
#  31: [46, 47],
#  34: [50, 51],
#  35: [52, 53],
#  39: [57, 58],
#  45: [64, 65],
#  51: [71, 72],
#  55: [76, 77],
#  56: [78, 79],
#  57: [80, 81],
#  59: [83, 84],
#  61: [86, 87],
#  63: [89, 90],
#  65: [92, 93, 94],
#  68: [97, 98],
#  71: [101, 102],
#  77: [108, 109],
#  87: [119, 120],
#  92: [125, 126],
#  95: [129, 130],
#  103: [138, 139],
#  104: [140, 141],
#  108: [145, 146],
#  109: [147, 148],
#  110: [149, 150]}

# %%
# Number of rows and columns per row based on the airplane configuration
number_of_seats = 174
number_of_rows = 29  # Rows are 1-indexed from 1 to 29
seats_per_row = 6    # 6 seats per row (0,1,2,3,4,5)
number_of_seats = 174
number_of_columns=seats_per_row
weight_f = 70 # weight female
weight_m = 85 # weight male
weight_d = 92.5 # weight disabled

# %% [markdown]
# ## Initialize the model

# %%
m = Model("airplane_seating")

# Weights is a dictionary mapping (i, j, k) to a weight, as discussed earlier

# Create decision variables for each seat and passenger
# The decision variable x will be a 3D dictionary with the keys being the row number,
# the seat within the row, and the unique identifier for each passenger.

AssignmenVarDict = {(i, j, k) : m.addVar(vtype = GRB.BINARY, name=f'passager_{i}_{j}_{k}')
                    for i in range(1, number_of_rows + 1)
                    for j in range(1, seats_per_row + 1)
                    for k in range(1, len(Passagers)+1)}

# %%
# # Create AdjacentVarDict only for pairs of passengers in the same group and not the same person
# AdjacentVarDict = {
#     (i1, j1, k1, k2): m.addVar(vtype=GRB.BINARY, name=f'adjacent_{i1}{j1}{k1}_{k2}')
#     for i1 in range(1, number_of_rows + 1)
#     for j1 in range(1, seats_per_row + 1)
#     for k1 in Passagers.keys()
#     for k2 in Passagers.keys()
#     if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
# }

# %% [markdown]
# ## Constraints

# %%
# Each passenger has a seat
SEATSASSIGNMENTCONST = m.addConstr(quicksum([AssignmenVarDict[(i, j, k)]
                                             for i in range(1, number_of_rows + 1)
                                             for j in range(1, seats_per_row + 1)
                                             for k in range(1,len(Passagers)+1)]) == len(Passagers))

# %%
# Each passenger must have one seat
PERSONSEATCONSTDIC = { k: m.addConstr(quicksum([AssignmenVarDict[(i, j, k)]
                                                for i in range(1, number_of_rows + 1)
                                                for j in range(1, seats_per_row + 1) ]) == 1)
                                                for k in range(1,len(Passagers)+1) }

# %%
# # Every seat is allocated to a single passenger
ALLOCATIONCONSTDIC = { (i,j) : m.addConstr(quicksum([AssignmenVarDict[(i,j,k)]
                                                     for k in range(1, len(Passagers)+1)])<=1)
                                                     for i in range(1, number_of_rows + 1)
                                                     for j in range(1, seats_per_row+1)  }

# %%
# Constraint Airplane Centrage

i_m = quicksum([weight_m * i* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==1])
i_f = quicksum([weight_m * i* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==0])
i_d = quicksum([weight_m * i* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==2])

i_bary = (i_m + i_f +i_d)/( weight_m * number_m + weight_f * number_f + weight_d * number_d)

j_m = quicksum([weight_m * j* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==1])
j_f = quicksum([weight_m * j* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==0])
j_d = quicksum([weight_m * j* AssignmenVarDict[(i, j, k)]
                for i in range(1, number_of_rows+1)
                for j in range(1, seats_per_row+1 )
                for k in range(1, len(Passagers)+1)
                if Passagers[k]['gender']==2])

j_bary = (j_m + j_f + j_d)/( weight_m * number_m + weight_f * number_f + weight_d * number_d)

IMAXBARYCONST = m.addConstr(i_bary <= 17)
IMINBARYCONST = m.addConstr(13 <= i_bary)
JMAXBARYCONST = m.addConstr(j_bary <= 4)
JMINBARYCONST = m.addConstr(3 <= j_bary)

# %%
# Constraints for the Disabled to be placed in front and in a certain way
DISABLEDCONSTR = m.addConstr(quicksum( [AssignmenVarDict[(i, j, k)] + AssignmenVarDict[(i, j-1, k)] + AssignmenVarDict[(i+1, j-1, k)] + AssignmenVarDict[(i+1, j, k)]
                      for i in range(1, number_of_rows)
                      for j in range(2, seats_per_row+1 )
                      for k in range(1, len(Passagers)+1)
                      if Passagers[k]['gender'] == 2 ])<=1)

# %% [markdown]
# # Linearisation ( variables + contraintes)

# %%
# Ajout des variables auxiliaires pour les passager i+1

AuxVarDict1 = {(i1, j1, k1, k2): m.addVar(vtype=GRB.BINARY, name=f"AuxVar_{i1}_{j1}_{k1}_{k2}") 
                for i1 in range(1, number_of_rows + 1) 
                for j1 in range(1, number_of_columns + 1) 
                for k1 in Passagers.keys()
                for k2 in Passagers.keys()
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
            }

        

# Ajout des contraintes pour linéariser les produits i+1
for i1 in range(1, number_of_rows + 1):
    for j1 in range(1, number_of_columns + 1):
        for k1 in Passagers.keys():
            for k2 in Passagers.keys():
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2:
                    # m.addConstr(AuxVarDict1[(i1, j1, k1, k2)] >= AssignmenVarDict.get((i1, j1, k1), 0) + AssignmenVarDict.get((i1 + 1, j1, k2), 0) - 1)
                    m.addConstr(AuxVarDict1[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1, k1), 0))
                    m.addConstr(AuxVarDict1[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1 + 1, j1, k2), 0))

# Ajout des variables auxiliaires pour les passager i-1

AuxVarDict2 = {(i1, j1, k1, k2): m.addVar(vtype=GRB.BINARY, name=f"AuxVar_{i1}_{j1}_{k1}_{k2}") 
                for i1 in range(1, number_of_rows + 1) 
                for j1 in range(1, number_of_columns + 1) 
                for k1 in Passagers.keys()
                for k2 in Passagers.keys()
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
            }

        

# Ajout des contraintes pour linéariser les produits i-1
for i1 in range(1, number_of_rows + 1):
    for j1 in range(1, number_of_columns + 1):
        for k1 in Passagers.keys():
            for k2 in Passagers.keys():
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2:
                    # m.addConstr(AuxVarDict2[(i1, j1, k1, k2)] >= AssignmenVarDict.get((i1, j1, k1), 0) + AssignmenVarDict.get((i1 - 1, j1, k2), 0) - 1)
                    m.addConstr(AuxVarDict2[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1, k1), 0))
                    m.addConstr(AuxVarDict2[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1 - 1, j1, k2), 0))

# Ajout des variables auxiliaires pour les passager j+1


AuxVarDict3 = {(i1, j1, k1, k2): m.addVar(vtype=GRB.BINARY, name=f"AuxVar_{i1}_{j1}_{k1}_{k2}") 
                for i1 in range(1, number_of_rows + 1) 
                for j1 in range(1, number_of_columns + 1) 
                for k1 in Passagers.keys()
                for k2 in Passagers.keys()
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
            }

            
        
# Ajout des contraintes pour linéariser les produits j+1
for i1 in range(1, number_of_rows + 1):
    for j1 in range(1, number_of_columns + 1):
        for k1 in Passagers.keys():
            for k2 in Passagers.keys():
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2:
                    # m.addConstr(AuxVarDict3[(i1, j1, k1, k2)] >= AssignmenVarDict.get((i1, j1, k1), 0) + AssignmenVarDict.get((i1, j1+1, k2), 0) - 1)
                    m.addConstr(AuxVarDict3[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1, k1), 0))
                    m.addConstr(AuxVarDict3[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1+1, k2), 0))
                    
# Ajout des variables auxiliaires pour les passager j-1

AuxVarDict4 = {(i1, j1, k1, k2): m.addVar(vtype=GRB.BINARY, name=f"AuxVar_{i1}_{j1}_{k1}_{k2}") 
                for i1 in range(1, number_of_rows + 1) 
                for j1 in range(1, number_of_columns + 1) 
                for k1 in Passagers.keys()
                for k2 in Passagers.keys()
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
            }

        

# Ajout des contraintes pour linéariser les produits j-1
for i1 in range(1, number_of_rows + 1):
    for j1 in range(1, number_of_columns + 1):
        for k1 in Passagers.keys():
            for k2 in Passagers.keys():
                if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2:
                    # m.addConstr(AuxVarDict4[(i1, j1, k1, k2)] >= AssignmenVarDict.get((i1, j1, k1), 0) + AssignmenVarDict.get((i1, j1-1, k2), 0) - 1)
                    m.addConstr(AuxVarDict4[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1, k1), 0))
                    m.addConstr(AuxVarDict4[(i1, j1, k1, k2)] <= AssignmenVarDict.get((i1, j1-1, k2), 0))

# %% [markdown]
# ## Objective Function

# %% [markdown]
# Nonlinéaire

# %%
# b=0.4
# a=0.1
# objective_groups = quicksum(
#     a * AssignmenVarDict.get((i1, j1, k1), 0) * AssignmenVarDict.get((i1 + 1, j1, k2), 0) +
#     a * AssignmenVarDict.get((i1, j1, k1), 0) * AssignmenVarDict.get((i1 - 1, j1, k2), 0) +
#     b * AssignmenVarDict.get((i1, j1, k1), 0) * AssignmenVarDict.get((i1, j1 + 1, k2), 0) +
#     b * AssignmenVarDict.get((i1, j1, k1), 0) * AssignmenVarDict.get((i1, j1 - 1, k2), 0)
#     for i1 in range(1, number_of_rows + 1)
#     for j1 in range(1, number_of_columns + 1)
#     for k1 in Passagers.keys()
#     for k2 in Passagers.keys()
#     if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
# )

# # Définition de l'objectif à maximiser
# m.setObjective(objective_groups, GRB.MAXIMIZE)

# %% [markdown]
# Linéaire

# %%
b=0.4 # poids pour  rang 
a=0.1 # poids pour  colonne 

objective_groups = sum(
    a*AuxVarDict1[(i1, j1, k1, k2)] + a*AuxVarDict2[(i1, j1, k1, k2)] + b*AuxVarDict3[(i1, j1, k1, k2)] + b*AuxVarDict4[(i1, j1, k1, k2)]
    for i1 in range(1, number_of_rows + 1)
    for j1 in range(1, number_of_columns + 1)
    for k1 in Passagers.keys()
    for k2 in Passagers.keys()
    if Passagers[k1]['group'] == Passagers[k2]['group'] and k1 != k2
)
m.setObjective(objective_groups, GRB.MAXIMIZE)

# %% [markdown]
# ## Optimize Model

# %%
# Run optimization and suppress output
m.Params.TimeLimit = 180

# Définir PreQLinearize à 1 pour activer la linéarisation des termes quadratiques ( pas besoin ici déja linéaire)
# m.Params.PreQLinearize = 1

m.update()
m.optimize()
# Out:
# Set parameter TimeLimit to value 180
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 23.0.0 23A344)
#
# CPU model: Apple M1 Pro
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 131179 rows, 91698 columns and 439034 nonzeros
# Model fingerprint: 0xae1765d9
# Variable types: 0 continuous, 91698 integer (91698 binary)
# Coefficient statistics:
#   Matrix range     [7e-03, 1e+00]
#   Objective range  [1e-01, 4e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 72006 rows and 36002 columns
# Presolve time: 0.98s
# Presolved: 59173 rows, 55696 columns, 264762 nonzeros
# Variable types: 0 continuous, 55696 integer (55696 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with primal simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 8.081839e+01, 16462 iterations, 1.52 seconds (2.71 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   80.81839    0 27061          -   80.81839      -     -    4s
# H    0     0                       0.8000000   80.81839      -     -    4s
# H    0     0                       6.8000000   80.81839  1089%     -    4s
# H    0     0                      16.6000000   80.81839   387%     -    5s
# H    0     0                      30.4000000   80.81839   166%     -    8s
#      0     0   80.56755    0 26162   30.40000   80.56755   165%     -   10s
# H    0     0                      30.6000000   79.76141   161%     -   15s
#      0     0   79.76141    0 18672   30.60000   79.76141   161%     -   16s
#      0     0   75.59241    0 9130   30.60000   75.59241   147%     -   27s
#      0     0   70.44366    0 8483   30.60000   70.44366   130%     -   36s
#      0     0   67.34535    0 8252   30.60000   67.34535   120%     -   48s
#      0     0   65.89360    0 5489   30.60000   65.89360   115%     -   56s
#      0     0   64.11217    0 4335   30.60000   64.11217   110%     -   75s
# H    0     0                      31.4000000   61.81305  96.9%     -  102s
#      0     0   61.81305    0 4343   31.40000   61.81305  96.9%     -  102s
# H    0     0                      32.0000000   58.08676  81.5%     -  131s
#      0     0   58.08676    0 2819   32.00000   58.08676  81.5%     -  132s
#      0     0   54.17438    0 1840   32.00000   54.17438  69.3%     -  159s
#      0     0   51.57248    0 2054   32.00000   51.57248  61.2%     -  178s
#      0     0          -    0        32.00000   51.57248  61.2%     -  180s
#
# Cutting planes:
#   Zero half: 246
#   RLT: 9573
#   BQP: 19463
#
# Explored 1 nodes (242515 simplex iterations) in 180.05 seconds (272.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 32 31.4 30.6 ... 0.8
#
# Time limit reached
# Best objective 3.200000000000e+01, best bound 5.140000000000e+01, gap 60.6250%

# %% [markdown]
# ## Graphic Seating Arrangement

# %%
seating_arrangement = {}
for i in range(1, number_of_rows + 1):
    for j in range(1, seats_per_row + 1):
        for k in Passagers.keys():
            if AssignmenVarDict[(i, j, k)].X > 0.5:  # Ensure the variable is part of the solution
                seating_arrangement[(i, j)] = k
print(f"Seating arrangement: {seating_arrangement}")
print(f'Optimal objective value (z*): {round(m.objVal, 2)}')
# Out:
# Seating arrangement: {(1, 2): 26, (1, 3): 27, (1, 4): 25, (1, 5): 24, (2, 1): 16, (2, 2): 11, (2, 3): 60, (2, 4): 116, (2, 5): 151, (2, 6): 20, (3, 1): 112, (3, 2): 129, (3, 3): 130, (3, 5): 109, (3, 6): 108, (4, 1): 12, (4, 2): 136, (4, 3): 75, (4, 4): 37, (4, 5): 38, (4, 6): 62, (5, 1): 101, (5, 2): 102, (5, 3): 59, (5, 5): 86, (5, 6): 87, (6, 1): 61, (6, 2): 120, (6, 3): 119, (6, 4): 147, (6, 5): 148, (6, 6): 82, (7, 1): 55, (7, 2): 78, (7, 3): 79, (7, 4): 67, (7, 5): 19, (7, 6): 54, (8, 1): 50, (8, 2): 51, (8, 3): 83, (8, 4): 84, (8, 5): 105, (8, 6): 142, (9, 1): 115, (9, 2): 145, (9, 3): 146, (9, 4): 128, (9, 5): 76, (9, 6): 77, (10, 1): 111, (10, 2): 1, (10, 4): 149, (10, 5): 150, (10, 6): 100, (11, 1): 81, (11, 2): 80, (11, 5): 113, (12, 1): 134, (12, 2): 99, (12, 3): 140, (12, 4): 141, (12, 5): 15, (12, 6): 122, (13, 1): 70, (13, 2): 124, (13, 3): 85, (13, 4): 21, (13, 5): 22, (13, 6): 56, (14, 1): 65, (14, 2): 64, (14, 3): 40, (14, 4): 143, (14, 5): 63, (14, 6): 66, (15, 2): 39, (15, 4): 42, (15, 5): 41, (16, 1): 74, (16, 4): 44, (16, 5): 114, (16, 6): 4, (17, 1): 48, (17, 2): 68, (17, 3): 127, (17, 4): 103, (17, 5): 132, (17, 6): 110, (18, 1): 33, (18, 2): 32, (18, 3): 96, (18, 4): 35, (18, 5): 36, (18, 6): 3, (19, 1): 123, (19, 2): 131, (19, 4): 73, (19, 5): 88, (20, 1): 57, (20, 2): 58, (20, 3): 91, (20, 5): 138, (20, 6): 139, (21, 1): 34, (21, 2): 144, (21, 3): 121, (22, 1): 43, (22, 2): 49, (22, 3): 2, (22, 4): 7, (22, 5): 133, (22, 6): 107, (23, 1): 14, (23, 2): 13, (23, 3): 8, (23, 4): 118, (23, 5): 53, (23, 6): 52, (24, 1): 137, (24, 2): 5, (24, 3): 6, (24, 5): 18, (24, 6): 17, (25, 1): 30, (25, 2): 28, (25, 3): 29, (25, 4): 31, (25, 5): 90, (25, 6): 89, (26, 1): 23, (26, 3): 94, (26, 4): 93, (26, 5): 92, (26, 6): 95, (27, 1): 69, (27, 2): 106, (27, 3): 126, (27, 4): 125, (27, 6): 45, (28, 1): 117, (28, 2): 135, (28, 3): 71, (28, 4): 72, (28, 5): 47, (28, 6): 46, (29, 1): 104, (29, 2): 10, (29, 3): 9, (29, 5): 98, (29, 6): 97}
# Optimal objective value (z*): 32.0

# %%
# Define the dimensions of the airplane
number_of_rows = 29
seats_per_row = 6

# Define the seating arrangement
seating_arrangement = seating_arrangement

# Create a plot
fig, ax = plt.subplots()

# Plot the seating arrangement
for seat, Passengers in seating_arrangement.items():
    ax.text(seat[1], seat[0], Passengers, ha='center', va='center')

# Mark positions without passengers
for i in range(1, number_of_rows + 1):
    for j in range(1, seats_per_row + 1):
        if (i, j) not in seating_arrangement:
            ax.scatter(j, i, color='red')

# Set the limits and labels of the plot
ax.set_xlim(0.5, seats_per_row + 0.5)
ax.set_ylim(0.5, number_of_rows + 0.5)
ax.set_xticks(range(1, seats_per_row + 1))
ax.set_yticks(range(1, number_of_rows + 1))
ax.set_xticklabels([chr(65 + i) for i in range(seats_per_row)]) # permet de générer les lettres A,B,C,D,E,F grâce à chr()
ax.set_yticklabels(range(1, number_of_rows + 1))
ax.grid(True)

# Add labels and title
plt.xlabel('Seats')
plt.ylabel('Rows')
plt.title('Seating Arrangement')

# Display the plot
plt.gca().invert_yaxis()  # Invert y-axis to match the plane layout
plt.show()

# %%
def generate_blue_gradations(num_gradations):
    gradations = []
    for i in range(num_gradations):
         # Linearly decrease the green component from full (255) to 0
        green_intensity = int(255 * (1 - i / (num_gradations - 1)))
        # Keep the red component at full intensity
        red_intensity = 255
        # Combine the components into a color value
        color_value = f"#{red_intensity:02X}{green_intensity:02X}00"
        gradations.append(color_value)
    return gradations
graduation = generate_blue_gradations(len(transit_times))
transit_times = list(transit_times)
transit_times.sort()

# %%
color_transit = dict()
for i in range(len(transit_times)):
    color_transit[transit_times[i]] = graduation[i]

# %%
data1 = [['Empty' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, seats_per_row + 1):
        for k in range(1, len(Passagers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passagers[k]['transit']!=float('inf'): colors1[i-1][j-1] = color_transit[Passagers[k]['transit']]
                else:
                    data2[i-1][j-4] = k
                    if Passagers[k]['transit']!=float('inf'): colors2[i-1][j-4] = color_transit[Passagers[k]['transit']]

# %%
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# ## Représentation Groupes

# %%
def generate_random_colors(num_colors):
    colors = []
    for _ in range(num_colors):

        red = random.randint(0, 255)
        green = random.randint(0, 255)
        blue = random.randint(0, 255)

        color_value = "#{:02X}{:02X}{:02X}".format(red, green, blue)
        colors.append(color_value)
    return colors

# %%
graduation = generate_random_colors(len(Groups))
color_group = {i : graduation[i-1] for i in range(1, len(Groups)+1)}

# %%
data1 = [['Empty' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]
data2 = [['Empty' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]

colors1 = [[ '#FFFFFF' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]
colors2 = [[ '#FFFFFF' for _ in range(seats_per_row//2)] for _ in range(number_of_rows)]

for i in range(1, number_of_rows + 1):
    for j in range(1, seats_per_row + 1):
        for k in range(1, len(Passagers) + 1):
            if AssignmenVarDict[(i,j,k)].x == 1:
                if j<4:
                    data1[i-1][j-1] = k
                    if Passagers[k]['group']in color_group: colors1[i-1][j-1] = color_group[Passagers[k]['group']]
                else:
                    data2[i-1][j-4] = k
                    if Passagers[k]['group'] in color_group: colors2[i-1][j-4] = color_group[Passagers[k]['group']]

# %%
def create_table(ax, data, colors):
    ax.set_axis_off()
    table = Table(ax, bbox=[0, 0, 1, 2])
    rows, cols = len(data), len(data[0])
    width, height = 100 , 100 


    for i in range(rows):
        for j in range(cols):
            table.add_cell(i, j, width, height, text=data[i][j], loc='center', facecolor=colors[i][j])

    ax.add_table(table)


fig, (ax1, ax2) = plt.subplots(1, 2)

create_table(ax1, data1, colors1)
create_table(ax2, data2, colors2)


ax1.annotate('Aisle', xy=(1, 1), xytext=(1.25, 1),
             textcoords='axes fraction', ha='center', va='center', color='red', fontsize=14)



plt.subplots_adjust(wspace=0.5)

plt.show()
